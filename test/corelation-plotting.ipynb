# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import sys
import os
import scipy
import math
from sklearn.metrics import r2_score
from pathlib import Path
import subprocess

from Bio.SeqIO import read, parse
import orthoani

from multiprocess import Pool
import pandas as pd

max_pool = 16
lim_file = 200

sys.path.append('../')
sys.path.append('../../')

# %%
from db_sketching.kmer_set import KMerSet, FracMinHash, TruncatedKMerSet, MeanFracMinHash

# %%
def cond(kmer_hash):
    hash = (976369 * kmer_hash + 1982627) % 10000
    if hash < 50:
        return True
    else:
        return False
    

def generate_polycond(degree, mod, c, seed_val):
    rng = np.random.default_rng(seed_val)
    coeffs = np.random.randint(
        low = 0,
        high = mod,
        size = degree+1
    )

    def poly_cond(kmer_hash):
        hash_mod = kmer_hash % mod
        end_val = 0
        for coeff in reversed(coeffs):
            end_val *= hash_mod
            end_val += coeff
            end_val %= mod

        return end_val < (mod / c)
    
    return poly_cond

def all_cond(kmer_hash):
    return True

# %%
data_home_dir = "../../data_temp"

species_analysis_type = "Single-Species"
species_analysis_data_dirs = {
    "Escherichia coli": (10,100),
    "Lactobacillus helveticus": (10,100),
    "Staphylococcus hominis": (10,100),
    "Mycoplasmoides pneumoniae": (10,100),
    "Brucella melitensis": (10,100),
    "Xanthomonas oryzae": (10,100)
}

genus_analysis_type = "Single-Genus"
genus_analysis_data_dirs = {
    "Pectobacterium": (10,35),
    "Morganella": (10,35),
    "Xylella": (10,35),
}

family_analysis_type = "Single-Family"
family_analysis_data_dirs = {
    "Enterobacteriaceae": (10,35),
    "Cyanobiaceae": (10,35),
    "Rhizobiaceae": (10,35)
}

family_genus_analysis_type = "Single-Family-Multi-Genus"
family_genus_analysis_data_dirs = {
    "31989": (10,35),
    "49546": (10,35),
    "186803": (10,35),
    "186817": (10,35),
}

genus_species_analysis_type = "Single-Genus-Multi-Species"
genus_species_analysis_data_dirs = {
    "Psychrobacter": (10,100),
    "Aeromonas": (10,100),
    "Rathayibacter": (10,100),
}

# %%
analysis_types = {
    species_analysis_type: species_analysis_data_dirs,
    genus_analysis_type: genus_analysis_data_dirs,
    family_analysis_type: family_analysis_data_dirs
}

# %%
c_val_range = (200,)

# %%
# Helper function to obtain genome files
def get_genome_files(data_home_dir, analysis_type, analysis_data_dir):
    genome_files = []
    collection_path = os.path.join(data_home_dir,analysis_type,analysis_data_dir)
    for filename in os.listdir(collection_path):
        full_filename = os.path.join(collection_path,filename)
        genome_files.append(full_filename)
    return genome_files

# %%
def check_genome_files(genome_files):
    checked_genome_files = []
    for file in genome_files:
        try:
            parsed_file = parse(file,"fasta")
            assert(len([record for record in parsed_file]) > 0)
            checked_genome_files.append(file)
        except:
            print(f"File {file} is damaged / invalid")

    return checked_genome_files

# %%
def get_genome_length(genome_file):
    genome_kmer = KMerSet(3)
    genome_kmer.insert_file(genome_file)
    return genome_kmer.length

def compute_length_parallel(genome_files):
    with Pool(max_pool) as p:
        return p.starmap(get_genome_length,([(g_file,) for g_file in genome_files]))

# %%
def compute_ortho_ani(genome_file_1, genome_file_2):
    try:
        genome_1_read = parse(genome_file_1,"fasta")
        genome_2_read = parse(genome_file_2,"fasta")
        ortho_ani_value = orthoani.orthoani(genome_1_read,genome_2_read)
        return ortho_ani_value
    except:
        return 0

def compute_ortho_ani_parallel(genome_files_1,genome_files_2):
    args = [(g1,g2) for g1,g2 in zip(genome_files_1,genome_files_2)]
    with Pool(max_pool) as p:
        return p.starmap(compute_ortho_ani,args)

def compute_pairwise_ortho(genome_files):
    genome_files_1, genome_files_2 = zip(*[(g1,g2) for g1 in genome_files for g2 in genome_files])
    return compute_ortho_ani_parallel(genome_files_1,genome_files_2)

# %%
def compute_kmer_sketches(genome_file, kmer_class, sketching_condition, kmer_length, canonical):
    genome_kmer = kmer_class(sketching_condition, kmer_length, canonical)
    genome_kmer.insert_file(genome_file)
    return genome_kmer

def compute_kmer_sketches_parallel(genome_files, kmer_length, kmer_class, sketching_cond, canonical):
    args = [(g,kmer_class,sketching_cond,kmer_length,canonical) for g in genome_files]
    with Pool(max_pool) as p:
        return p.starmap(compute_kmer_sketches,args)


def compute_kmer_ani(genome_1_kmer, genome_2_kmer):    
    kmer_estimated_ani = genome_1_kmer.ANI_estimation(genome_2_kmer)
    return kmer_estimated_ani


def compute_kmer_ani_parallel(kmer_sketches_1,kmer_sketches_2):
    args = [(s1,s2) for s1,s2 in zip(kmer_sketches_1,kmer_sketches_2)]
    with Pool(max_pool) as p:
        return p.starmap(compute_kmer_ani,args)

# %%
ortho_ani_filename = "../../data_temp/ortho_ani_values.csv"
ortho_ani_dataframe = pd.read_csv(ortho_ani_filename,index_col=0)
print(ortho_ani_dataframe)
# Out:
#                                          genome_file_1  \
# 0       ../../data_temp/Single-Genus/Salmonella/64.fna
# 1       ../../data_temp/Single-Genus/Salmonella/32.fna
# 2       ../../data_temp/Single-Genus/Salmonella/99.fna
# 3       ../../data_temp/Single-Genus/Salmonella/43.fna
# 4        ../../data_temp/Single-Genus/Salmonella/7.fna
# ..                                                 ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/441...
# 495  ../../data_temp/Single-Family/Rhizobiaceae/292...
# 496  ../../data_temp/Single-Family/Rhizobiaceae/83.fna
# 497  ../../data_temp/Single-Family/Rhizobiaceae/129...
# 498  ../../data_temp/Single-Family/Rhizobiaceae/291...
#
#                                          genome_file_2  orthoani_val  \
# 0       ../../data_temp/Single-Genus/Salmonella/32.fna      0.985312
# 1       ../../data_temp/Single-Genus/Salmonella/99.fna      0.984921
# 2       ../../data_temp/Single-Genus/Salmonella/43.fna      0.983598
# 3        ../../data_temp/Single-Genus/Salmonella/7.fna      0.984154
# 4       ../../data_temp/Single-Genus/Salmonella/98.fna      0.986997
# ..                                                 ...           ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/292...      0.780533
# 495  ../../data_temp/Single-Family/Rhizobiaceae/83.fna      0.781226
# 496  ../../data_temp/Single-Family/Rhizobiaceae/129...      0.994015
# 497  ../../data_temp/Single-Family/Rhizobiaceae/291...      0.997140
# 498  ../../data_temp/Single-Family/Rhizobiaceae/110...      0.997200
#
#      analysis_type analysis_data_dir
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# ..             ...               ...
# 494  Single-Family      Rhizobiaceae
# 495  Single-Family      Rhizobiaceae
# 496  Single-Family      Rhizobiaceae
# 497  Single-Family      Rhizobiaceae
# 498  Single-Family      Rhizobiaceae
#
# [2586 rows x 5 columns]

# %%
kmer_sketch_ani_filename = "../../data_temp/kmer_sketch_ani_values.csv"
kmer_sketch_dataframe = pd.read_csv(kmer_sketch_ani_filename,index_col=0)
print(kmer_sketch_dataframe)
# Out:
#                                          genome_file_1  \
# 0    ../../data_temp/Single-Species/Escherichia col...
# 1    ../../data_temp/Single-Species/Escherichia col...
# 2    ../../data_temp/Single-Species/Escherichia col...
# 3    ../../data_temp/Single-Species/Escherichia col...
# 4    ../../data_temp/Single-Species/Escherichia col...
# ..                                                 ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/441...
# 495  ../../data_temp/Single-Family/Rhizobiaceae/292...
# 496  ../../data_temp/Single-Family/Rhizobiaceae/83.fna
# 497  ../../data_temp/Single-Family/Rhizobiaceae/129...
# 498  ../../data_temp/Single-Family/Rhizobiaceae/291...
#
#                                          genome_file_2  kmer_length  c_val  \
# 0    ../../data_temp/Single-Species/Escherichia col...           10     20
# 1    ../../data_temp/Single-Species/Escherichia col...           10     20
# 2    ../../data_temp/Single-Species/Escherichia col...           10     20
# 3    ../../data_temp/Single-Species/Escherichia col...           10     20
# 4    ../../data_temp/Single-Species/Escherichia col...           10     20
# ..                                                 ...          ...    ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/292...           18    200
# 495  ../../data_temp/Single-Family/Rhizobiaceae/83.fna           18    200
# 496  ../../data_temp/Single-Family/Rhizobiaceae/129...           18    200
# 497  ../../data_temp/Single-Family/Rhizobiaceae/291...           18    200
# 498  ../../data_temp/Single-Family/Rhizobiaceae/110...           18    200
#
#      canonical  kmer_ani_val  analysis_type analysis_data_dir
# 0         True      0.996998            NaN               NaN
# 1         True      0.997966            NaN               NaN
# 2         True      0.999697            NaN               NaN
# 3         True      0.999718            NaN               NaN
# 4         True      0.999652            NaN               NaN
# ..         ...           ...            ...               ...
# 494       True      0.815396  Single-Family      Rhizobiaceae
# 495       True      0.790726  Single-Family      Rhizobiaceae
# 496       True      0.995510  Single-Family      Rhizobiaceae
# 497       True      0.997465  Single-Family      Rhizobiaceae
# 498       True      0.997827  Single-Family      Rhizobiaceae
#
# [134171 rows x 8 columns]

# %%
corrleation_filename = "../../data_temp/correlation_values.csv"
correlation_dataframe = pd.read_csv(corrleation_filename,index_col=0)
print(correlation_dataframe)
# Out:
#     kmer_length  c_val  canonical  pearson_coeff  pearson_coeff_pval  \
# 0            10     20       True       0.907790        2.218581e-38
# 0            10     20      False       0.421223        1.413929e-05
# 0            10     50       True       0.911519        3.280371e-39
# 0            10     50      False       0.425088        1.155857e-05
# 0            10    100       True       0.916422        2.327374e-40
# ..          ...    ...        ...            ...                 ...
# 0            14    200       True       0.990251        0.000000e+00
# 0            15    200       True       0.994699        0.000000e+00
# 0            16    200       True       0.996540        0.000000e+00
# 0            17    200       True       0.997151        0.000000e+00
# 0            18    200       True       0.997380        0.000000e+00
#
#     spearman_coeff  spearman_coeff_pval   analysis_type analysis_data_dir  \
# 0         0.866259         5.424778e-31  Single-Species  Escherichia coli
# 0         0.482028         4.377992e-07  Single-Species  Escherichia coli
# 0         0.872789         5.627322e-32  Single-Species  Escherichia coli
# 0         0.478169         5.570930e-07  Single-Species  Escherichia coli
# 0         0.869019         2.112540e-31  Single-Species  Escherichia coli
# ..             ...                  ...             ...               ...
# 0         0.949570        1.752926e-252   Single-Family      Rhizobiaceae
# 0         0.958773        1.006453e-273   Single-Family      Rhizobiaceae
# 0         0.959566        8.882844e-276   Single-Family      Rhizobiaceae
# 0         0.962064        1.601490e-282   Single-Family      Rhizobiaceae
# 0         0.963136        1.473122e-285   Single-Family      Rhizobiaceae
#
#     r2_val  dropped_zeros  r2_val_raw  r2_val_lin
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# ..     ...            ...         ...         ...
# 0      NaN            0.0    0.794739    0.802663
# 0      NaN            0.0    0.910607    0.916799
# 0      NaN            0.0    0.957661    0.962572
# 0      NaN            0.0    0.966761    0.970991
# 0      NaN            0.0    0.967316    0.971219
#
# [1129 rows x 13 columns]

# %%
kmer_class = FracMinHash

# %%
iteration = 0

for analysis_type in analysis_types:
    for analysis_data_dir in analysis_types[analysis_type]:
        genome_files = get_genome_files(data_home_dir,analysis_type,analysis_data_dir)
        checked_genome_files = check_genome_files(genome_files)

        print(f"{analysis_type=}, {analysis_data_dir=}")
        print(f"Using genome files {checked_genome_files}")
        
        checked_genome_files_off1 = checked_genome_files[1:]

        ortho_ani_condition = (
            ortho_ani_dataframe["genome_file_1"].isin(checked_genome_files)
        )

        filtered_ortho_ani_dataframe = ortho_ani_dataframe[ortho_ani_condition]
        complement_ortho_ani_dataframe = ortho_ani_dataframe[~ortho_ani_condition]

        if len(filtered_ortho_ani_dataframe) == 0:
            print("Computing OrthoANI values ...")
            ortho_ani_vals = compute_ortho_ani_parallel(checked_genome_files,checked_genome_files_off1)
            print("Computed OrthoANI values")
        else:
            print("Using previously computed OrthoANI values")
            ortho_ani_vals = filtered_ortho_ani_dataframe["orthoani_val"]

        computed_ortho_ani_dataframe = pd.DataFrame(
            {
                "analysis_type": analysis_type,
                "analysis_data_dir": analysis_data_dir,
                "genome_file_1": checked_genome_files[:-1],
                "genome_file_2": checked_genome_files_off1,
                "orthoani_val": ortho_ani_vals
            }
        )
        ortho_ani_dataframe = pd.concat([complement_ortho_ani_dataframe,computed_ortho_ani_dataframe])

        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]
        
        for kmer_length in range(min_kmer_length,max_kmer_length+1):
            for c_val in c_val_range:
                canon = True

                iteration += 1

                print(f"ITERATION {iteration} : {kmer_length=}, {c_val=}, {canon=}")

                checked_genome_files_off1 = checked_genome_files[1:]

                kmer_sketch_ani_condition = (
                    (kmer_sketch_dataframe["genome_file_1"].isin(checked_genome_files)) &
                    (kmer_sketch_dataframe["kmer_length"] == kmer_length) &
                    (kmer_sketch_dataframe["c_val"] == c_val) &
                    (kmer_sketch_dataframe["canonical"] == canon)
                )

                filtered_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[kmer_sketch_ani_condition]
                complement_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[~kmer_sketch_ani_condition]

                if len(filtered_kmer_sketch_ani_dataframe) == 0:
                    polycond = generate_polycond(3,1000000007,c_val,iteration)
                    print("Computing sketches ...")
                    kmer_sketches = compute_kmer_sketches_parallel(
                        checked_genome_files,
                        kmer_length = kmer_length,
                        kmer_class = kmer_class,
                        sketching_cond = polycond,
                        canonical = canon
                    )
                    kmer_sketches_off1 = kmer_sketches[1:]
                    print("Sketching complete, computing ani ...")
                    kmer_ani_vals = compute_kmer_ani_parallel(kmer_sketches,kmer_sketches_off1)
                    print("ANI computation complete")
                else:
                    print("Using previously computed ANI values")
                    kmer_ani_vals = filtered_kmer_sketch_ani_dataframe["kmer_ani_val"]


                num_entries = len(kmer_ani_vals)
                
                computed_kmer_sketch_ani_dataframe = pd.DataFrame(
                    {
                        "analysis_type": analysis_type,
                        "analysis_data_dir": analysis_data_dir,
                        "genome_file_1": checked_genome_files[:-1],
                        "genome_file_2": checked_genome_files_off1,
                        "kmer_length": [kmer_length for _ in range(num_entries)],
                        "c_val": [c_val for _ in range(num_entries)],
                        "canonical": [canon for _ in range(num_entries)],
                        "kmer_ani_val": kmer_ani_vals
                    }
                )


                kmer_sketch_dataframe = pd.concat(
                    [complement_kmer_sketch_ani_dataframe,computed_kmer_sketch_ani_dataframe]
                )

                correlation_condition = (
                    (correlation_dataframe["analysis_type"] == analysis_type) &
                    (correlation_dataframe["analysis_data_dir"] == analysis_data_dir) &
                    (correlation_dataframe["kmer_length"] == kmer_length) &
                    (correlation_dataframe["c_val"] == c_val) & 
                    (correlation_dataframe["canonical"] == canon)
                )

                filtered_correlation_dataframe = correlation_dataframe[~correlation_condition] # remove to recompute

                print("Computing correlations...")


                # filtered_ortho_ani_dataframe = ortho_ani_dataframe[ortho_ani_condition]
                # filtered_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[kmer_sketch_ani_condition]

                # combined_ani_dataframe = filtered_ortho_ani_dataframe.merge(filtered_kmer_sketch_ani_dataframe)


                # ortho_ani_vals = combined_ani_dataframe["orthoani_val"]
                # kmer_ani_vals = combined_ani_dataframe["kmer_ani_val"]

                
                filter_o, filter_k = zip(*[(o,k) for o,k in zip(ortho_ani_vals,kmer_ani_vals) if (k > 0 and o > 0)])

                dropped_zeros = len(ortho_ani_vals) - len(filter_o)
                pearson_coeff = scipy.stats.pearsonr(filter_o,filter_k)
                spearman_coeff = scipy.stats.spearmanr(filter_o,filter_k)

                lin_fit = np.poly1d(np.polyfit(filter_o, filter_k, 1))
                r2_val_raw = r2_score(filter_o,filter_k)
                r2_val_lin = r2_score(filter_o,[lin_fit(o) for o in filter_o])



                correlation_dataframe = pd.concat([filtered_correlation_dataframe,
                    pd.DataFrame({
                        "analysis_type": analysis_type,
                        "analysis_data_dir": analysis_data_dir,
                        "kmer_length": [kmer_length],
                        "c_val": [c_val],
                        "canonical": [canon],
                        "pearson_coeff" : [pearson_coeff.statistic],
                        "pearson_coeff_pval" : [pearson_coeff.pvalue],
                        "spearman_coeff" : [spearman_coeff.statistic],
                        "spearman_coeff_pval" : [spearman_coeff.pvalue],
                        "r2_val_raw": [r2_val_raw],
                        "r2_val_lin": [r2_val_lin],
                        "dropped_zeros": dropped_zeros
                    })],
                )
# Out:
# analysis_type='Single-Species', analysis_data_dir='Escherichia coli'
# Using genome files ['../../data_temp/Single-Species/Escherichia coli/64.fna', '../../data_temp/Single-Species/Escherichia coli/32.fna', '../../data_temp/Single-Species/Escherichia coli/99.fna', '../../data_temp/Single-Species/Escherichia coli/43.fna', '../../data_temp/Single-Species/Escherichia coli/7.fna', '../../data_temp/Single-Species/Escherichia coli/98.fna', '../../data_temp/Single-Species/Escherichia coli/58.fna', '../../data_temp/Single-Species/Escherichia coli/90.fna', '../../data_temp/Single-Species/Escherichia coli/14.fna', '../../data_temp/Single-Species/Escherichia coli/41.fna', '../../data_temp/Single-Species/Escherichia coli/67.fna', '../../data_temp/Single-Species/Escherichia coli/73.fna', '../../data_temp/Single-Species/Escherichia coli/17.fna', '../../data_temp/Single-Species/Escherichia coli/56.fna', '../../data_temp/Single-Species/Escherichia coli/50.fna', '../../data_temp/Single-Species/Escherichia coli/2.fna', '../../data_temp/Single-Species/Escherichia coli/46.fna', '../../data_temp/Single-Species/Escherichia coli/52.fna', '../../data_temp/Single-Species/Escherichia coli/65.fna', '../../data_temp/Single-Species/Escherichia coli/95.fna', '../../data_temp/Single-Species/Escherichia coli/45.fna', '../../data_temp/Single-Species/Escherichia coli/74.fna', '../../data_temp/Single-Species/Escherichia coli/44.fna', '../../data_temp/Single-Species/Escherichia coli/12.fna', '../../data_temp/Single-Species/Escherichia coli/94.fna', '../../data_temp/Single-Species/Escherichia coli/25.fna', '../../data_temp/Single-Species/Escherichia coli/60.fna', '../../data_temp/Single-Species/Escherichia coli/39.fna', '../../data_temp/Single-Species/Escherichia coli/22.fna', '../../data_temp/Single-Species/Escherichia coli/48.fna', '../../data_temp/Single-Species/Escherichia coli/88.fna', '../../data_temp/Single-Species/Escherichia coli/24.fna', '../../data_temp/Single-Species/Escherichia coli/9.fna', '../../data_temp/Single-Species/Escherichia coli/86.fna', '../../data_temp/Single-Species/Escherichia coli/5.fna', '../../data_temp/Single-Species/Escherichia coli/89.fna', '../../data_temp/Single-Species/Escherichia coli/71.fna', '../../data_temp/Single-Species/Escherichia coli/54.fna', '../../data_temp/Single-Species/Escherichia coli/23.fna', '../../data_temp/Single-Species/Escherichia coli/49.fna', '../../data_temp/Single-Species/Escherichia coli/40.fna', '../../data_temp/Single-Species/Escherichia coli/18.fna', '../../data_temp/Single-Species/Escherichia coli/4.fna', '../../data_temp/Single-Species/Escherichia coli/20.fna', '../../data_temp/Single-Species/Escherichia coli/63.fna', '../../data_temp/Single-Species/Escherichia coli/33.fna', '../../data_temp/Single-Species/Escherichia coli/87.fna', '../../data_temp/Single-Species/Escherichia coli/80.fna', '../../data_temp/Single-Species/Escherichia coli/26.fna', '../../data_temp/Single-Species/Escherichia coli/1.fna', '../../data_temp/Single-Species/Escherichia coli/47.fna', '../../data_temp/Single-Species/Escherichia coli/92.fna', '../../data_temp/Single-Species/Escherichia coli/51.fna', '../../data_temp/Single-Species/Escherichia coli/37.fna', '../../data_temp/Single-Species/Escherichia coli/84.fna', '../../data_temp/Single-Species/Escherichia coli/53.fna', '../../data_temp/Single-Species/Escherichia coli/70.fna', '../../data_temp/Single-Species/Escherichia coli/42.fna', '../../data_temp/Single-Species/Escherichia coli/57.fna', '../../data_temp/Single-Species/Escherichia coli/72.fna', '../../data_temp/Single-Species/Escherichia coli/91.fna', '../../data_temp/Single-Species/Escherichia coli/27.fna', '../../data_temp/Single-Species/Escherichia coli/19.fna', '../../data_temp/Single-Species/Escherichia coli/66.fna', '../../data_temp/Single-Species/Escherichia coli/13.fna', '../../data_temp/Single-Species/Escherichia coli/16.fna', '../../data_temp/Single-Species/Escherichia coli/29.fna', '../../data_temp/Single-Species/Escherichia coli/8.fna', '../../data_temp/Single-Species/Escherichia ...
# Using previously computed OrthoANI values
# ITERATION 1 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 2 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 3 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 4 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 5 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 6 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 7 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 8 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 9 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 10 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 11 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 12 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 13 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 14 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 15 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 16 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 17 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 18 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 19 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 20 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 21 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 22 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 23 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 24 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 25 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 26 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 27 : kmer_length=36, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 28 : kmer_length=37, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 29 : kmer_length=38, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 30 : kmer_length=39, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 31 : kmer_length=40, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 32 : kmer_length=41, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 33 : kmer_length=42, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 34 : kmer_length=43, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 35 : kmer_length=44, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 36 : kmer_length=45, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 37 : kmer_length=46, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 38 : kmer_length=47, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 39 : kmer_length=48, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 40 : kmer_length=49, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 41 : kmer_length=50, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 42 : kmer_length=51, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 43 : kmer_length=52, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 44 : kmer_length=53, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 45 : kmer_length=54, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 46 : kmer_length=55, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 47 : kmer_length=56, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 48 : kmer_length=57, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 49 : kmer_length=58, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 50 : kmer_length=59, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 51 : kmer_length=60, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 52 : kmer_length=61, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 53 : kmer_length=62, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 54 : kmer_length=63, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 55 : kmer_length=64, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 56 : kmer_length=65, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 57 : kmer_length=66, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 58 : kmer_length=67, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 59 : kmer_length=68, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 60 : kmer_length=69, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 61 : kmer_length=70, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 62 : kmer_length=71, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 63 : kmer_length=72, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 64 : kmer_length=73, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 65 : kmer_length=74, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 66 : kmer_length=75, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 67 : kmer_length=76, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 68 : kmer_length=77, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 69 : kmer_length=78, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 70 : kmer_length=79, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 71 : kmer_length=80, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 72 : kmer_length=81, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 73 : kmer_length=82, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 74 : kmer_length=83, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 75 : kmer_length=84, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 76 : kmer_length=85, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 77 : kmer_length=86, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 78 : kmer_length=87, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 79 : kmer_length=88, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 80 : kmer_length=89, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 81 : kmer_length=90, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 82 : kmer_length=91, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 83 : kmer_length=92, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 84 : kmer_length=93, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 85 : kmer_length=94, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 86 : kmer_length=95, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 87 : kmer_length=96, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 88 : kmer_length=97, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 89 : kmer_length=98, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 90 : kmer_length=99, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 91 : kmer_length=100, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Species', analysis_data_dir='Lactobacillus helveticus'
# Using genome files ['../../data_temp/Single-Species/Lactobacillus helveticus/64.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/32.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/99.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/43.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/7.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/98.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/58.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/90.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/14.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/41.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/67.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/73.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/17.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/56.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/50.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/2.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/46.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/52.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/65.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/95.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/45.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/74.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/44.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/12.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/94.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/25.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/60.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/39.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/22.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/48.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/88.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/24.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/9.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/86.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/5.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/89.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/71.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/54.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/23.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/49.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/40.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/18.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/4.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/20.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/63.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/33.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/87.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/80.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/26.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/1.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/47.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/92.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/51.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/37.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/84.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/53.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/70.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/42.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/57.fna', '../../data_temp/Single-Species/Lactobacillus helveticus/72.fna', '../../data_temp/Single-Sp ...
# Using previously computed OrthoANI values
# ITERATION 92 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 93 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 94 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 95 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 96 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 97 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 98 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 99 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 100 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 101 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 102 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 103 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 104 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 105 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 106 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 107 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 108 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 109 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 110 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 111 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 112 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 113 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 114 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 115 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 116 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 117 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 118 : kmer_length=36, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 119 : kmer_length=37, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 120 : kmer_length=38, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 121 : kmer_length=39, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 122 : kmer_length=40, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 123 : kmer_length=41, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 124 : kmer_length=42, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 125 : kmer_length=43, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 126 : kmer_length=44, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 127 : kmer_length=45, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 128 : kmer_length=46, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 129 : kmer_length=47, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 130 : kmer_length=48, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 131 : kmer_length=49, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 132 : kmer_length=50, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 133 : kmer_length=51, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 134 : kmer_length=52, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 135 : kmer_length=53, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 136 : kmer_length=54, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 137 : kmer_length=55, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 138 : kmer_length=56, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 139 : kmer_length=57, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 140 : kmer_length=58, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 141 : kmer_length=59, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 142 : kmer_length=60, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 143 : kmer_length=61, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 144 : kmer_length=62, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 145 : kmer_length=63, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 146 : kmer_length=64, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 147 : kmer_length=65, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 148 : kmer_length=66, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 149 : kmer_length=67, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 150 : kmer_length=68, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 151 : kmer_length=69, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 152 : kmer_length=70, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 153 : kmer_length=71, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 154 : kmer_length=72, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 155 : kmer_length=73, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 156 : kmer_length=74, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 157 : kmer_length=75, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 158 : kmer_length=76, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 159 : kmer_length=77, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 160 : kmer_length=78, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 161 : kmer_length=79, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 162 : kmer_length=80, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 163 : kmer_length=81, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 164 : kmer_length=82, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 165 : kmer_length=83, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 166 : kmer_length=84, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 167 : kmer_length=85, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 168 : kmer_length=86, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 169 : kmer_length=87, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 170 : kmer_length=88, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 171 : kmer_length=89, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 172 : kmer_length=90, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 173 : kmer_length=91, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 174 : kmer_length=92, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 175 : kmer_length=93, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 176 : kmer_length=94, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 177 : kmer_length=95, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 178 : kmer_length=96, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 179 : kmer_length=97, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 180 : kmer_length=98, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 181 : kmer_length=99, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 182 : kmer_length=100, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Species', analysis_data_dir='Staphylococcus hominis'
# Using genome files ['../../data_temp/Single-Species/Staphylococcus hominis/64.fna', '../../data_temp/Single-Species/Staphylococcus hominis/32.fna', '../../data_temp/Single-Species/Staphylococcus hominis/99.fna', '../../data_temp/Single-Species/Staphylococcus hominis/43.fna', '../../data_temp/Single-Species/Staphylococcus hominis/7.fna', '../../data_temp/Single-Species/Staphylococcus hominis/98.fna', '../../data_temp/Single-Species/Staphylococcus hominis/58.fna', '../../data_temp/Single-Species/Staphylococcus hominis/90.fna', '../../data_temp/Single-Species/Staphylococcus hominis/14.fna', '../../data_temp/Single-Species/Staphylococcus hominis/41.fna', '../../data_temp/Single-Species/Staphylococcus hominis/67.fna', '../../data_temp/Single-Species/Staphylococcus hominis/73.fna', '../../data_temp/Single-Species/Staphylococcus hominis/17.fna', '../../data_temp/Single-Species/Staphylococcus hominis/56.fna', '../../data_temp/Single-Species/Staphylococcus hominis/50.fna', '../../data_temp/Single-Species/Staphylococcus hominis/2.fna', '../../data_temp/Single-Species/Staphylococcus hominis/46.fna', '../../data_temp/Single-Species/Staphylococcus hominis/52.fna', '../../data_temp/Single-Species/Staphylococcus hominis/65.fna', '../../data_temp/Single-Species/Staphylococcus hominis/95.fna', '../../data_temp/Single-Species/Staphylococcus hominis/45.fna', '../../data_temp/Single-Species/Staphylococcus hominis/74.fna', '../../data_temp/Single-Species/Staphylococcus hominis/44.fna', '../../data_temp/Single-Species/Staphylococcus hominis/12.fna', '../../data_temp/Single-Species/Staphylococcus hominis/94.fna', '../../data_temp/Single-Species/Staphylococcus hominis/25.fna', '../../data_temp/Single-Species/Staphylococcus hominis/60.fna', '../../data_temp/Single-Species/Staphylococcus hominis/39.fna', '../../data_temp/Single-Species/Staphylococcus hominis/22.fna', '../../data_temp/Single-Species/Staphylococcus hominis/48.fna', '../../data_temp/Single-Species/Staphylococcus hominis/88.fna', '../../data_temp/Single-Species/Staphylococcus hominis/24.fna', '../../data_temp/Single-Species/Staphylococcus hominis/9.fna', '../../data_temp/Single-Species/Staphylococcus hominis/86.fna', '../../data_temp/Single-Species/Staphylococcus hominis/5.fna', '../../data_temp/Single-Species/Staphylococcus hominis/89.fna', '../../data_temp/Single-Species/Staphylococcus hominis/71.fna', '../../data_temp/Single-Species/Staphylococcus hominis/54.fna', '../../data_temp/Single-Species/Staphylococcus hominis/23.fna', '../../data_temp/Single-Species/Staphylococcus hominis/49.fna', '../../data_temp/Single-Species/Staphylococcus hominis/40.fna', '../../data_temp/Single-Species/Staphylococcus hominis/18.fna', '../../data_temp/Single-Species/Staphylococcus hominis/4.fna', '../../data_temp/Single-Species/Staphylococcus hominis/20.fna', '../../data_temp/Single-Species/Staphylococcus hominis/63.fna', '../../data_temp/Single-Species/Staphylococcus hominis/33.fna', '../../data_temp/Single-Species/Staphylococcus hominis/87.fna', '../../data_temp/Single-Species/Staphylococcus hominis/80.fna', '../../data_temp/Single-Species/Staphylococcus hominis/26.fna', '../../data_temp/Single-Species/Staphylococcus hominis/1.fna', '../../data_temp/Single-Species/Staphylococcus hominis/47.fna', '../../data_temp/Single-Species/Staphylococcus hominis/92.fna', '../../data_temp/Single-Species/Staphylococcus hominis/51.fna', '../../data_temp/Single-Species/Staphylococcus hominis/37.fna', '../../data_temp/Single-Species/Staphylococcus hominis/84.fna', '../../data_temp/Single-Species/Staphylococcus hominis/53.fna', '../../data_temp/Single-Species/Staphylococcus hominis/70.fna', '../../data_temp/Single-Species/Staphylococcus hominis/42.fna', '../../data_temp/Single-Species/Staphylococcus hominis/57.fna', '../../data_temp/Single-Species/Staphylococcus hominis/72.fna', '../../data_temp/Single-Species/Staphylococcus hominis/91.fna', '../../data_temp/Single-Species/Staphylococcus hominis/27.fna', '../../data_temp/S ...
# Using previously computed OrthoANI values
# ITERATION 183 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 184 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 185 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 186 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 187 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 188 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 189 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 190 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 191 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 192 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 193 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 194 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 195 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 196 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 197 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 198 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 199 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 200 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 201 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 202 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 203 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 204 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 205 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 206 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 207 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 208 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 209 : kmer_length=36, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 210 : kmer_length=37, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 211 : kmer_length=38, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 212 : kmer_length=39, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 213 : kmer_length=40, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 214 : kmer_length=41, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 215 : kmer_length=42, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 216 : kmer_length=43, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 217 : kmer_length=44, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 218 : kmer_length=45, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 219 : kmer_length=46, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 220 : kmer_length=47, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 221 : kmer_length=48, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 222 : kmer_length=49, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 223 : kmer_length=50, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 224 : kmer_length=51, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 225 : kmer_length=52, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 226 : kmer_length=53, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 227 : kmer_length=54, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 228 : kmer_length=55, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 229 : kmer_length=56, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 230 : kmer_length=57, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 231 : kmer_length=58, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 232 : kmer_length=59, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 233 : kmer_length=60, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 234 : kmer_length=61, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 235 : kmer_length=62, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 236 : kmer_length=63, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 237 : kmer_length=64, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 238 : kmer_length=65, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 239 : kmer_length=66, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 240 : kmer_length=67, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 241 : kmer_length=68, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 242 : kmer_length=69, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 243 : kmer_length=70, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 244 : kmer_length=71, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 245 : kmer_length=72, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 246 : kmer_length=73, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 247 : kmer_length=74, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 248 : kmer_length=75, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 249 : kmer_length=76, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 250 : kmer_length=77, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 251 : kmer_length=78, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 252 : kmer_length=79, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 253 : kmer_length=80, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 254 : kmer_length=81, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 255 : kmer_length=82, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 256 : kmer_length=83, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 257 : kmer_length=84, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 258 : kmer_length=85, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 259 : kmer_length=86, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 260 : kmer_length=87, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 261 : kmer_length=88, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 262 : kmer_length=89, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 263 : kmer_length=90, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 264 : kmer_length=91, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 265 : kmer_length=92, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 266 : kmer_length=93, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 267 : kmer_length=94, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 268 : kmer_length=95, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 269 : kmer_length=96, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 270 : kmer_length=97, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 271 : kmer_length=98, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 272 : kmer_length=99, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 273 : kmer_length=100, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Species', analysis_data_dir='Mycoplasmoides pneumoniae'
# ...
# ITERATION 628 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 629 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 630 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 631 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 632 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 633 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 634 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 635 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 636 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 637 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 638 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 639 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 640 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 641 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 642 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 643 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 644 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 645 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Family', analysis_data_dir='Cyanobiaceae'
# Using genome files ['../../data_temp/Single-Family/Cyanobiaceae/479.fna', '../../data_temp/Single-Family/Cyanobiaceae/306.fna', '../../data_temp/Single-Family/Cyanobiaceae/228.fna', '../../data_temp/Single-Family/Cyanobiaceae/404.fna', '../../data_temp/Single-Family/Cyanobiaceae/112.fna', '../../data_temp/Single-Family/Cyanobiaceae/164.fna', '../../data_temp/Single-Family/Cyanobiaceae/429.fna', '../../data_temp/Single-Family/Cyanobiaceae/367.fna', '../../data_temp/Single-Family/Cyanobiaceae/64.fna', '../../data_temp/Single-Family/Cyanobiaceae/491.fna', '../../data_temp/Single-Family/Cyanobiaceae/236.fna', '../../data_temp/Single-Family/Cyanobiaceae/130.fna', '../../data_temp/Single-Family/Cyanobiaceae/281.fna', '../../data_temp/Single-Family/Cyanobiaceae/287.fna', '../../data_temp/Single-Family/Cyanobiaceae/413.fna', '../../data_temp/Single-Family/Cyanobiaceae/300.fna', '../../data_temp/Single-Family/Cyanobiaceae/252.fna', '../../data_temp/Single-Family/Cyanobiaceae/140.fna', '../../data_temp/Single-Family/Cyanobiaceae/32.fna', '../../data_temp/Single-Family/Cyanobiaceae/379.fna', '../../data_temp/Single-Family/Cyanobiaceae/222.fna', '../../data_temp/Single-Family/Cyanobiaceae/153.fna', '../../data_temp/Single-Family/Cyanobiaceae/350.fna', '../../data_temp/Single-Family/Cyanobiaceae/102.fna', '../../data_temp/Single-Family/Cyanobiaceae/430.fna', '../../data_temp/Single-Family/Cyanobiaceae/488.fna', '../../data_temp/Single-Family/Cyanobiaceae/99.fna', '../../data_temp/Single-Family/Cyanobiaceae/172.fna', '../../data_temp/Single-Family/Cyanobiaceae/446.fna', '../../data_temp/Single-Family/Cyanobiaceae/448.fna', '../../data_temp/Single-Family/Cyanobiaceae/385.fna', '../../data_temp/Single-Family/Cyanobiaceae/152.fna', '../../data_temp/Single-Family/Cyanobiaceae/316.fna', '../../data_temp/Single-Family/Cyanobiaceae/162.fna', '../../data_temp/Single-Family/Cyanobiaceae/321.fna', '../../data_temp/Single-Family/Cyanobiaceae/439.fna', '../../data_temp/Single-Family/Cyanobiaceae/128.fna', '../../data_temp/Single-Family/Cyanobiaceae/314.fna', '../../data_temp/Single-Family/Cyanobiaceae/191.fna', '../../data_temp/Single-Family/Cyanobiaceae/177.fna', '../../data_temp/Single-Family/Cyanobiaceae/43.fna', '../../data_temp/Single-Family/Cyanobiaceae/212.fna', '../../data_temp/Single-Family/Cyanobiaceae/260.fna', '../../data_temp/Single-Family/Cyanobiaceae/452.fna', '../../data_temp/Single-Family/Cyanobiaceae/315.fna', '../../data_temp/Single-Family/Cyanobiaceae/421.fna', '../../data_temp/Single-Family/Cyanobiaceae/384.fna', '../../data_temp/Single-Family/Cyanobiaceae/7.fna', '../../data_temp/Single-Family/Cyanobiaceae/98.fna', '../../data_temp/Single-Family/Cyanobiaceae/213.fna', '../../data_temp/Single-Family/Cyanobiaceae/58.fna', '../../data_temp/Single-Family/Cyanobiaceae/425.fna', '../../data_temp/Single-Family/Cyanobiaceae/392.fna', '../../data_temp/Single-Family/Cyanobiaceae/493.fna', '../../data_temp/Single-Family/Cyanobiaceae/283.fna', '../../data_temp/Single-Family/Cyanobiaceae/90.fna', '../../data_temp/Single-Family/Cyanobiaceae/473.fna', '../../data_temp/Single-Family/Cyanobiaceae/440.fna', '../../data_temp/Single-Family/Cyanobiaceae/147.fna', '../../data_temp/Single-Family/Cyanobiaceae/133.fna', '../../data_temp/Single-Family/Cyanobiaceae/168.fna', '../../data_temp/Single-Family/Cyanobiaceae/266.fna', '../../data_temp/Single-Family/Cyanobiaceae/149.fna', '../../data_temp/Single-Family/Cyanobiaceae/221.fna', '../../data_temp/Single-Family/Cyanobiaceae/151.fna', '../../data_temp/Single-Family/Cyanobiaceae/141.fna', '../../data_temp/Single-Family/Cyanobiaceae/347.fna', '../../data_temp/Single-Family/Cyanobiaceae/135.fna', '../../data_temp/Single-Family/Cyanobiaceae/233.fna', '../../data_temp/Single-Family/Cyanobiaceae/492.fna', '../../data_temp/Single-Family/Cyanobiaceae/14.fna', '../../data_temp/Single-Family/Cyanobiaceae/363.fna', '../../data_temp/Single-Family/Cyanobiaceae/499.fna', '../../data_temp/Single-Family/Cyanobiaceae/41.f ...
# Using previously computed OrthoANI values
# ITERATION 646 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 647 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 648 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 649 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 650 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 651 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 652 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 653 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 654 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 655 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 656 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 657 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 658 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 659 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 660 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 661 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 662 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 663 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 664 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 665 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 666 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 667 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 668 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 669 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 670 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 671 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Family', analysis_data_dir='Rhizobiaceae'
# Using genome files ['../../data_temp/Single-Family/Rhizobiaceae/479.fna', '../../data_temp/Single-Family/Rhizobiaceae/306.fna', '../../data_temp/Single-Family/Rhizobiaceae/228.fna', '../../data_temp/Single-Family/Rhizobiaceae/404.fna', '../../data_temp/Single-Family/Rhizobiaceae/112.fna', '../../data_temp/Single-Family/Rhizobiaceae/164.fna', '../../data_temp/Single-Family/Rhizobiaceae/429.fna', '../../data_temp/Single-Family/Rhizobiaceae/367.fna', '../../data_temp/Single-Family/Rhizobiaceae/64.fna', '../../data_temp/Single-Family/Rhizobiaceae/491.fna', '../../data_temp/Single-Family/Rhizobiaceae/236.fna', '../../data_temp/Single-Family/Rhizobiaceae/130.fna', '../../data_temp/Single-Family/Rhizobiaceae/281.fna', '../../data_temp/Single-Family/Rhizobiaceae/287.fna', '../../data_temp/Single-Family/Rhizobiaceae/413.fna', '../../data_temp/Single-Family/Rhizobiaceae/300.fna', '../../data_temp/Single-Family/Rhizobiaceae/252.fna', '../../data_temp/Single-Family/Rhizobiaceae/140.fna', '../../data_temp/Single-Family/Rhizobiaceae/32.fna', '../../data_temp/Single-Family/Rhizobiaceae/379.fna', '../../data_temp/Single-Family/Rhizobiaceae/222.fna', '../../data_temp/Single-Family/Rhizobiaceae/153.fna', '../../data_temp/Single-Family/Rhizobiaceae/350.fna', '../../data_temp/Single-Family/Rhizobiaceae/102.fna', '../../data_temp/Single-Family/Rhizobiaceae/430.fna', '../../data_temp/Single-Family/Rhizobiaceae/488.fna', '../../data_temp/Single-Family/Rhizobiaceae/99.fna', '../../data_temp/Single-Family/Rhizobiaceae/172.fna', '../../data_temp/Single-Family/Rhizobiaceae/446.fna', '../../data_temp/Single-Family/Rhizobiaceae/448.fna', '../../data_temp/Single-Family/Rhizobiaceae/385.fna', '../../data_temp/Single-Family/Rhizobiaceae/152.fna', '../../data_temp/Single-Family/Rhizobiaceae/316.fna', '../../data_temp/Single-Family/Rhizobiaceae/162.fna', '../../data_temp/Single-Family/Rhizobiaceae/321.fna', '../../data_temp/Single-Family/Rhizobiaceae/439.fna', '../../data_temp/Single-Family/Rhizobiaceae/128.fna', '../../data_temp/Single-Family/Rhizobiaceae/314.fna', '../../data_temp/Single-Family/Rhizobiaceae/191.fna', '../../data_temp/Single-Family/Rhizobiaceae/177.fna', '../../data_temp/Single-Family/Rhizobiaceae/43.fna', '../../data_temp/Single-Family/Rhizobiaceae/212.fna', '../../data_temp/Single-Family/Rhizobiaceae/260.fna', '../../data_temp/Single-Family/Rhizobiaceae/452.fna', '../../data_temp/Single-Family/Rhizobiaceae/315.fna', '../../data_temp/Single-Family/Rhizobiaceae/421.fna', '../../data_temp/Single-Family/Rhizobiaceae/384.fna', '../../data_temp/Single-Family/Rhizobiaceae/7.fna', '../../data_temp/Single-Family/Rhizobiaceae/98.fna', '../../data_temp/Single-Family/Rhizobiaceae/213.fna', '../../data_temp/Single-Family/Rhizobiaceae/58.fna', '../../data_temp/Single-Family/Rhizobiaceae/425.fna', '../../data_temp/Single-Family/Rhizobiaceae/392.fna', '../../data_temp/Single-Family/Rhizobiaceae/493.fna', '../../data_temp/Single-Family/Rhizobiaceae/283.fna', '../../data_temp/Single-Family/Rhizobiaceae/90.fna', '../../data_temp/Single-Family/Rhizobiaceae/473.fna', '../../data_temp/Single-Family/Rhizobiaceae/440.fna', '../../data_temp/Single-Family/Rhizobiaceae/147.fna', '../../data_temp/Single-Family/Rhizobiaceae/133.fna', '../../data_temp/Single-Family/Rhizobiaceae/168.fna', '../../data_temp/Single-Family/Rhizobiaceae/266.fna', '../../data_temp/Single-Family/Rhizobiaceae/149.fna', '../../data_temp/Single-Family/Rhizobiaceae/221.fna', '../../data_temp/Single-Family/Rhizobiaceae/151.fna', '../../data_temp/Single-Family/Rhizobiaceae/141.fna', '../../data_temp/Single-Family/Rhizobiaceae/347.fna', '../../data_temp/Single-Family/Rhizobiaceae/135.fna', '../../data_temp/Single-Family/Rhizobiaceae/233.fna', '../../data_temp/Single-Family/Rhizobiaceae/492.fna', '../../data_temp/Single-Family/Rhizobiaceae/14.fna', '../../data_temp/Single-Family/Rhizobiaceae/363.fna', '../../data_temp/Single-Family/Rhizobiaceae/499.fna', '../../data_temp/Single-Family/Rhizobiaceae/41.f ...
# Using previously computed OrthoANI values
# ITERATION 672 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 673 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 674 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 675 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 676 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 677 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 678 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 679 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 680 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 681 : kmer_length=19, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 682 : kmer_length=20, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 683 : kmer_length=21, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 684 : kmer_length=22, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 685 : kmer_length=23, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 686 : kmer_length=24, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 687 : kmer_length=25, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 688 : kmer_length=26, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 689 : kmer_length=27, c_val=200, canon=True
# Computing sketches ...
# Sketching complete, computing ani ...
# ANI computation complete
# Computing correlations...
# ITERATION 690 : kmer_length=28, c_val=200, canon=True
# Computing sketches ...

# %%
print(ortho_ani_dataframe)

# %%
print(kmer_sketch_dataframe)

# %%
print(correlation_dataframe)

# %%
ortho_ani_dataframe.to_csv(ortho_ani_filename)
kmer_sketch_dataframe.to_csv(kmer_sketch_ani_filename)
correlation_dataframe.to_csv(corrleation_filename)

# %%
def box_plot_OrthoANI(
    analysis_type, 
    ortho_ani_dataframe
):
    plt.figure(figsize=(20,10),dpi=300)
    
    plt.title(f"Box Plot of OrthoANI values for {analysis_type}")
    
    
    filtered_ortho_ani_df = ortho_ani_dataframe[ortho_ani_dataframe["analysis_type"] == analysis_type]

    plt.boxplot(
        [filtered_ortho_ani_df[filtered_ortho_ani_df["analysis_data_dir"] == analysis_data_dir]["orthoani_val"] for analysis_data_dir in analysis_types[analysis_type]],
        labels=[analysis_data_dir for analysis_data_dir in analysis_types[analysis_type]],
    )
    plt.ylabel("OrthoAni Value")

    plt.savefig(f"../../plots/correlations/{analysis_type}-OrthoANI-boxplot.png")
    plt.close()

# %%
def plot_correlation(
        analysis_type, 
        correlation_dataframe,
        c_val_range,
        correlation_string,
    ):

    

    plt.figure(figsize=(10,10),dpi=300)
    plt.xlabel("K-mer Length")
    plt.ylabel(correlation_string)
    plt.title(f"{correlation_string} of {kmer_class.__name__} ANI Esimtation against K-mer Length on {analysis_type}") 
    for analysis_data_dir in analysis_types[analysis_type]:
        analysis_correlation_dataframe = correlation_dataframe[
            (correlation_dataframe["analysis_type"] == analysis_type) 
            & (correlation_dataframe["analysis_data_dir"] == analysis_data_dir)
        ]
        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]
        kmer_lengths = [kmer_length for kmer_length in range(min_kmer_length,max_kmer_length+1)]
        canonical = True

        filtered_correlation_dataframe = analysis_correlation_dataframe[
            analysis_correlation_dataframe["canonical"] == canonical
        ]
        
        
        for c_val in c_val_range:
            correlation = list(
                filtered_correlation_dataframe[
                    (filtered_correlation_dataframe["c_val"] == c_val) &
                    (filtered_correlation_dataframe["kmer_length"].isin(set(kmer_lengths)))
                ][correlation_string]
            )
            print(len(kmer_lengths))
            print(len(correlation))
            # plt.scatter(kmer_lengths,correlation,label=f"{analysis_data_dir}",s=[3 for _ in range(len(kmer_lengths))])
            plt.plot(kmer_lengths,correlation,label=f"{analysis_data_dir}")

    plt.legend()
    plt.plot()
    plt.savefig(f"../../plots/correlations/{analysis_type}-{kmer_class.__name__}-{canonical=}-{correlation_string}.png")
    plt.close()

# %%
for analysis_type in analysis_types:
    for correlation_string in ["pearson_coeff","spearman_coeff","r2_val_raw","r2_val_lin","dropped_zeros"]:
        plot_correlation(
            analysis_type=analysis_type,
            correlation_dataframe=correlation_dataframe,
            c_val_range=c_val_range,
            correlation_string=correlation_string
        )
    
    box_plot_OrthoANI(
        analysis_type=analysis_type,
        ortho_ani_dataframe=ortho_ani_dataframe
    )

    # analysis_correlation_dataframe = correlation_dataframe[
    #     (correlation_dataframe["analysis_type"] == analysis_type) &
    #     (correlation_dataframe["analysis_data_dir"] == analysis_data_dir)
    # ]

    # for canonical in (True,):
    #     filtered_correlation_dataframe = analysis_correlation_dataframe[
    #         analysis_correlation_dataframe["canonical"] == canonical
    #     ]
    #     plt.figure(figsize=(10,10),dpi=300)
    #     plt.xlabel("K-mer Length")
    #     plt.ylabel("Pearson Correlation")
    #     plt.title("Pearson Correlation of FracMinHash ANI Esimtation against K-mer Length at different c-value thresholds")

    #     for c_val in c_val_range:
    #         pearson_correlation = list(
    #             filtered_correlation_dataframe[
    #                 (filtered_correlation_dataframe["c_val"] == c_val) &
    #                 (filtered_correlation_dataframe["kmer_length"].isin(set(range(min_kmer_length,max_kmer_length+1))))
    #             ]["pearson_coeff"]
    #         )
    #         print(len(kmer_lengths))
    #         print(len(pearson_correlation))
    #         plt.scatter(kmer_lengths,pearson_correlation,label=f"c = {c_val}")

    #     plt.legend()
    #     plt.plot()
    #     plt.savefig(f"../../plots/correlations/{analysis_type}-{analysis_data_dir}-{kmer_class.__name__}-{canonical=}-pearson.png")
    #     plt.close()




    #     plt.figure(figsize=(10,10),dpi=300)
    #     plt.xlabel("K-mer Length")
    #     plt.ylabel("Spearman Correlation")
    #     plt.title("Spearman Correlation of FracMinHash ANI Esimtation against K-mer Length at different c-value thresholds")

    #     for c_val in c_val_range:
    #         spearman_correlation = [ 
    #             filtered_correlation_dataframe[
    #                 (filtered_correlation_dataframe["c_val"] == c_val) &
    #                 (filtered_correlation_dataframe["kmer_length"] == kmer_length)
    #             ]["spearman_coeff"]
    #             for kmer_length in range(min_kmer_length,max_kmer_length+1)
    #         ]
    #         print(kmer_lengths)
    #         print(spearman_correlation)
    #         plt.scatter(kmer_lengths,spearman_correlation,label=f"c = {c_val}")

    #     plt.legend()
    #     plt.plot()
    #     plt.savefig(f"../../plots/correlations/{analysis_type}-{analysis_data_dir}-{kmer_class.__name__}-{canonical=}-spearman.png")
    #     plt.close()

# %%
import imageio

def plot_single_kmer(
        ortho_vals_df,
        kmer_vals_df,
        kmer_length,
):
    
    Path(f"../../plots/temp/{analysis_type}-{analysis_data_dir}/").mkdir(parents=True, exist_ok=True)
    combined_df = pd.merge(ortho_vals_df,kmer_vals_df)
    ortho_vals = combined_df["orthoani_val"]
    kmer_vals = combined_df["kmer_ani_val"]
    fig = plt.figure(figsize=(10,10),dpi=300)
    ax = fig.add_subplot()
    filter_o, filter_k = zip(*[(o,k) for o,k in zip(ortho_vals,kmer_vals) if (k > 0 and o > 0)])
    lin_fit = np.poly1d(np.polyfit(filter_o, filter_k, 1))
    ax.plot(filter_o,filter_o,"r-")
    ax.scatter(filter_o,filter_k,marker="^",s=[2 for _ in filter_o])
    # ax.scatter(filter_o,filter_o,marker="o",s=[2 for _ in filter_o])
    ax.plot(np.unique(filter_o), lin_fit(np.unique(filter_o)))
    plt.figtext(0.7,0.15,f"Zeros dropped : {len(ortho_vals) - len(filter_o)}")
    pearson_coeff = scipy.stats.pearsonr(filter_o,filter_k)

    plt.figtext(0.7,0.17,f"Pearson Corr. Coeff.: {pearson_coeff.statistic:.3f}")
    plt.figtext(0.7,0.19,f"Pearson Corr. p.: {pearson_coeff.pvalue:.3e}")



    ax.legend(["OrthoANI",f"{kmer_length}-mer dots",f"{kmer_length}-mer line : {lin_fit}"])

    plotname = f"../../plots/temp/{analysis_type}-{analysis_data_dir}/{analysis_type}-{analysis_data_dir}-{kmer_length}mer-estimated-ANI.png"
    plt.savefig(plotname)
    plt.close()
    return plotname

# %%
for analysis_type in analysis_types:
    for analysis_data_dir in analysis_types[analysis_type]:
        Path(f"../../plots/{analysis_type}-{analysis_data_dir}/").mkdir(parents=True, exist_ok=True)

        analysis_images = []
        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]

        for kmer_length in range(min_kmer_length,max_kmer_length+1):
            for c_val in c_val_range:
                canon = True
                analysis_images.append(
                    imageio.v3.imread(
                        plot_single_kmer(
                            ortho_vals_df = ortho_ani_dataframe[
                                (ortho_ani_dataframe["analysis_type"] == analysis_type)
                                & (ortho_ani_dataframe["analysis_data_dir"] == analysis_data_dir)
                            ],
                            kmer_vals_df = kmer_sketch_dataframe[
                                (kmer_sketch_dataframe["analysis_type"] == analysis_type)
                                & (kmer_sketch_dataframe["analysis_data_dir"] == analysis_data_dir)
                                & (kmer_sketch_dataframe["kmer_length"] == kmer_length)
                                & (kmer_sketch_dataframe["c_val"] == c_val)
                                & (kmer_sketch_dataframe["canonical"] == canon)
                            ],
                            kmer_length= kmer_length,
                        )
                    )
                )
        
        print(len(analysis_images))
        plot_gif_filename = f"../../plots/{analysis_type}-{analysis_data_dir}/{analysis_type}-{analysis_data_dir}-estimated-ANI.gif"
        imageio.mimsave(plot_gif_filename,analysis_images,duration=0.5)
