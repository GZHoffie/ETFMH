# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import sys
import os
import scipy
import math
from sklearn.metrics import r2_score
from pathlib import Path
import subprocess

from Bio.SeqIO import read, parse
import orthoani

from multiprocess import Pool
import pandas as pd

max_pool = 16
lim_file = 200

sys.path.append('../')
sys.path.append('../../')

# %%
from db_sketching.kmer_set import KMerSet, FracMinHash, TruncatedKMerSet, MeanFracMinHash

# %%
def cond(kmer_hash):
    hash = (976369 * kmer_hash + 1982627) % 10000
    if hash < 50:
        return True
    else:
        return False
    

def generate_polycond(degree, mod, c, seed_val):
    rng = np.random.default_rng(seed_val)
    coeffs = np.random.randint(
        low = 0,
        high = mod,
        size = degree+1
    )

    def poly_cond(kmer_hash):
        hash_mod = kmer_hash % mod
        end_val = 0
        for coeff in reversed(coeffs):
            end_val *= hash_mod
            end_val += coeff
            end_val %= mod

        return end_val < (mod / c)
    
    return poly_cond

def all_cond(kmer_hash):
    return True

# %%
ANALYSIS_TYPE = "analysis_type"
ANALYSIS_DATA_DIR = "analysis_data_dir"
GENOME_FILE_1 = "genome_file_1"
GENOME_FILE_2 = "genome_file_2"
ORTHOANI_VAL = "orthoani_val"
KMER_LENGTH = "kmer_length"
C_VAL = "c_val"
CANONICAL = "canonical"
KMER_ANI_VAL = "kmer_ani_val"
PEARSON_COEFF = "pearson_coeff"
PEARSON_COEFF_PVAL = "pearson_coeff_pval"
SPEARMAN_COEFF = "spearman_coeff"
SPEARMAN_COEFF_PVAL = "spearman_coeff_pval"
R2_VAL_RAW = "r2_val_raw"
R2_VAL_LIN = "r2_val_lin"
DROPPED_ZEROS = "dropped_zeros"

# %%
data_home_dir = "../../data_temp"

species_analysis_type = "Single-Species"
species_analysis_data_dirs = {
    "Escherichia coli": (10,100),
    "Lactobacillus helveticus": (10,100),
    "Staphylococcus hominis": (10,100),
    "Mycoplasmoides pneumoniae": (10,100),
    "Brucella melitensis": (10,100),
    "Xanthomonas oryzae": (10,100)
}

genus_analysis_type = "Single-Genus"
genus_analysis_data_dirs = {
    "Pectobacterium": (10,35),
    "Morganella": (10,35),
    "Xylella": (10,35),
}

family_analysis_type = "Single-Family"
family_analysis_data_dirs = {
    "Enterobacteriaceae": (10,35),
    "Cyanobiaceae": (10,35),
    "Rhizobiaceae": (10,35)
}

family_genus_analysis_type = "Single-Family-Multi-Genus"
family_genus_analysis_data_dirs = {
    "31989": (10,35),
    "49546": (10,35),
    "186803": (10,35),
    "186817": (10,35),
}

genus_species_analysis_type = "Single-Genus-Multi-Species"
genus_species_analysis_data_dirs = {
    "Psychrobacter": (10,35),
    "Aeromonas": (10,35),
    "Rathayibacter": (10,35),
}

# %%
analysis_types = {
    species_analysis_type: species_analysis_data_dirs,
    genus_analysis_type: genus_analysis_data_dirs,
    family_analysis_type: family_analysis_data_dirs,
    family_genus_analysis_type: family_genus_analysis_data_dirs,
    genus_species_analysis_type: genus_species_analysis_data_dirs
}

# %%
c_val_range = (200,)

# %%
# Helper function to obtain genome files
def get_genome_files(data_home_dir, analysis_type, analysis_data_dir):
    genome_files = []
    collection_path = os.path.join(data_home_dir,analysis_type,analysis_data_dir)
    for filename in os.listdir(collection_path):
        full_filename = os.path.join(collection_path,filename)
        genome_files.append(full_filename)
    return genome_files

# %%
def check_genome_files(genome_files):
    checked_genome_files = []
    for file in genome_files:
        try:
            parsed_file = parse(file,"fasta")
            assert(len([record for record in parsed_file]) > 0)
            checked_genome_files.append(file)
        except:
            print(f"File {file} is damaged / invalid")

    return checked_genome_files

# %%
def get_genome_length(genome_file):
    genome_kmer = KMerSet(3)
    genome_kmer.insert_file(genome_file)
    return genome_kmer.length

def compute_length_parallel(genome_files):
    with Pool(max_pool) as p:
        return p.starmap(get_genome_length,([(g_file,) for g_file in genome_files]))

# %%
def compute_ortho_ani(genome_file_1, genome_file_2):
    try:
        genome_1_read = parse(genome_file_1,"fasta")
        genome_2_read = parse(genome_file_2,"fasta")
        ortho_ani_value = orthoani.orthoani(genome_1_read,genome_2_read)
        return ortho_ani_value
    except:
        return 0

def compute_ortho_ani_parallel(genome_files_1,genome_files_2):
    args = [(g1,g2) for g1,g2 in zip(genome_files_1,genome_files_2)]
    with Pool(max_pool) as p:
        return p.starmap(compute_ortho_ani,args)

def compute_pairwise_ortho(genome_files):
    genome_files_1, genome_files_2 = zip(*[(g1,g2) for g1 in genome_files for g2 in genome_files])
    return compute_ortho_ani_parallel(genome_files_1,genome_files_2)

# %%
def compute_kmer_sketches(genome_file, kmer_class, sketching_condition, kmer_length, canonical):
    genome_kmer = kmer_class(sketching_condition, kmer_length, canonical)
    genome_kmer.insert_file(genome_file)
    return genome_kmer

def compute_kmer_sketches_parallel(genome_files, kmer_length, kmer_class, sketching_cond, canonical):
    args = [(g,kmer_class,sketching_cond,kmer_length,canonical) for g in genome_files]
    with Pool(max_pool) as p:
        return p.starmap(compute_kmer_sketches,args)


def compute_kmer_ani(genome_1_kmer, genome_2_kmer):    
    kmer_estimated_ani = genome_1_kmer.ANI_estimation(genome_2_kmer)
    return kmer_estimated_ani


def compute_kmer_ani_parallel(kmer_sketches_1,kmer_sketches_2):
    args = [(s1,s2) for s1,s2 in zip(kmer_sketches_1,kmer_sketches_2)]
    with Pool(max_pool) as p:
        return p.starmap(compute_kmer_ani,args)

# %%
ortho_ani_filename = "../../data_temp/ortho_ani_values.csv"
ortho_ani_dataframe = pd.read_csv(ortho_ani_filename,index_col=0)
print(ortho_ani_dataframe)
# Out:
#                                          genome_file_1  \
# 0       ../../data_temp/Single-Genus/Salmonella/64.fna
# 1       ../../data_temp/Single-Genus/Salmonella/32.fna
# 2       ../../data_temp/Single-Genus/Salmonella/99.fna
# 3       ../../data_temp/Single-Genus/Salmonella/43.fna
# 4        ../../data_temp/Single-Genus/Salmonella/7.fna
# ..                                                 ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/441...
# 495  ../../data_temp/Single-Family/Rhizobiaceae/292...
# 496  ../../data_temp/Single-Family/Rhizobiaceae/83.fna
# 497  ../../data_temp/Single-Family/Rhizobiaceae/129...
# 498  ../../data_temp/Single-Family/Rhizobiaceae/291...
#
#                                          genome_file_2  orthoani_val  \
# 0       ../../data_temp/Single-Genus/Salmonella/32.fna      0.985312
# 1       ../../data_temp/Single-Genus/Salmonella/99.fna      0.984921
# 2       ../../data_temp/Single-Genus/Salmonella/43.fna      0.983598
# 3        ../../data_temp/Single-Genus/Salmonella/7.fna      0.984154
# 4       ../../data_temp/Single-Genus/Salmonella/98.fna      0.986997
# ..                                                 ...           ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/292...      0.780533
# 495  ../../data_temp/Single-Family/Rhizobiaceae/83.fna      0.781226
# 496  ../../data_temp/Single-Family/Rhizobiaceae/129...      0.994015
# 497  ../../data_temp/Single-Family/Rhizobiaceae/291...      0.997140
# 498  ../../data_temp/Single-Family/Rhizobiaceae/110...      0.997200
#
#      analysis_type analysis_data_dir
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# ..             ...               ...
# 494  Single-Family      Rhizobiaceae
# 495  Single-Family      Rhizobiaceae
# 496  Single-Family      Rhizobiaceae
# 497  Single-Family      Rhizobiaceae
# 498  Single-Family      Rhizobiaceae
#
# [2586 rows x 5 columns]

# %%
kmer_sketch_ani_filename = "../../data_temp/kmer_sketch_ani_values.csv"
kmer_sketch_dataframe = pd.read_csv(kmer_sketch_ani_filename,index_col=0)
print(kmer_sketch_dataframe)
# Out:
#                                          genome_file_1  \
# 0    ../../data_temp/Single-Species/Escherichia col...
# 1    ../../data_temp/Single-Species/Escherichia col...
# 2    ../../data_temp/Single-Species/Escherichia col...
# 3    ../../data_temp/Single-Species/Escherichia col...
# 4    ../../data_temp/Single-Species/Escherichia col...
# ..                                                 ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/441...
# 495  ../../data_temp/Single-Family/Rhizobiaceae/292...
# 496  ../../data_temp/Single-Family/Rhizobiaceae/83.fna
# 497  ../../data_temp/Single-Family/Rhizobiaceae/129...
# 498  ../../data_temp/Single-Family/Rhizobiaceae/291...
#
#                                          genome_file_2  kmer_length  c_val  \
# 0    ../../data_temp/Single-Species/Escherichia col...           10     20
# 1    ../../data_temp/Single-Species/Escherichia col...           10     20
# 2    ../../data_temp/Single-Species/Escherichia col...           10     20
# 3    ../../data_temp/Single-Species/Escherichia col...           10     20
# 4    ../../data_temp/Single-Species/Escherichia col...           10     20
# ..                                                 ...          ...    ...
# 494  ../../data_temp/Single-Family/Rhizobiaceae/292...           35    200
# 495  ../../data_temp/Single-Family/Rhizobiaceae/83.fna           35    200
# 496  ../../data_temp/Single-Family/Rhizobiaceae/129...           35    200
# 497  ../../data_temp/Single-Family/Rhizobiaceae/291...           35    200
# 498  ../../data_temp/Single-Family/Rhizobiaceae/110...           35    200
#
#      canonical  kmer_ani_val  analysis_type analysis_data_dir
# 0         True      0.996998            NaN               NaN
# 1         True      0.997966            NaN               NaN
# 2         True      0.999697            NaN               NaN
# 3         True      0.999718            NaN               NaN
# 4         True      0.999652            NaN               NaN
# ..         ...           ...            ...               ...
# 494       True      0.849250  Single-Family      Rhizobiaceae
# 495       True      0.840393  Single-Family      Rhizobiaceae
# 496       True      0.995491  Single-Family      Rhizobiaceae
# 497       True      0.997652  Single-Family      Rhizobiaceae
# 498       True      0.997943  Single-Family      Rhizobiaceae
#
# [142654 rows x 8 columns]

# %%
corrleation_filename = "../../data_temp/correlation_values.csv"
correlation_dataframe = pd.read_csv(corrleation_filename,index_col=0)
print(correlation_dataframe)
# Out:
#     kmer_length  c_val  canonical  pearson_coeff  pearson_coeff_pval  \
# 0            10     20       True       0.907790        2.218581e-38
# 0            10     20      False       0.421223        1.413929e-05
# 0            10     50       True       0.911519        3.280371e-39
# 0            10     50      False       0.425088        1.155857e-05
# 0            10    100       True       0.916422        2.327374e-40
# ..          ...    ...        ...            ...                 ...
# 0            31    200       True       0.997971        0.000000e+00
# 0            32    200       True       0.998233        0.000000e+00
# 0            33    200       True       0.998213        0.000000e+00
# 0            34    200       True       0.998040        0.000000e+00
# 0            35    200       True       0.997898        0.000000e+00
#
#     spearman_coeff  spearman_coeff_pval   analysis_type analysis_data_dir  \
# 0         0.866259         5.424778e-31  Single-Species  Escherichia coli
# 0         0.482028         4.377992e-07  Single-Species  Escherichia coli
# 0         0.872789         5.627322e-32  Single-Species  Escherichia coli
# 0         0.478169         5.570930e-07  Single-Species  Escherichia coli
# 0         0.869019         2.112540e-31  Single-Species  Escherichia coli
# ..             ...                  ...             ...               ...
# 0         0.972592        4.972939e-317   Single-Family      Rhizobiaceae
# 0         0.972661        2.666582e-317   Single-Family      Rhizobiaceae
# 0         0.973296        8.426784e-320   Single-Family      Rhizobiaceae
# 0         0.973959        1.778636e-322   Single-Family      Rhizobiaceae
# 0         0.974057        6.916919e-323   Single-Family      Rhizobiaceae
#
#     r2_val  dropped_zeros  r2_val_raw  r2_val_lin
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# 0      NaN            NaN         NaN         NaN
# ..     ...            ...         ...         ...
# 0      NaN            0.0    0.862895    0.864895
# 0      NaN            0.0    0.851731    0.853408
# 0      NaN            0.0    0.844561    0.846218
# 0      NaN            0.0    0.834326    0.836093
# 0      NaN            0.0    0.839144    0.841070
#
# [1146 rows x 13 columns]

# %%
kmer_class = FracMinHash

# %%
iteration = 0

for analysis_type in analysis_types:
    for analysis_data_dir in analysis_types[analysis_type]:
        genome_files = get_genome_files(data_home_dir,analysis_type,analysis_data_dir)
        checked_genome_files = check_genome_files(genome_files)

        print(f"{analysis_type=}, {analysis_data_dir=}")
        print(f"Using genome files {checked_genome_files}")
        
        checked_genome_files_off1 = checked_genome_files[1:]

        ortho_ani_condition = (
            ortho_ani_dataframe["genome_file_1"].isin(checked_genome_files)
        )

        filtered_ortho_ani_dataframe = ortho_ani_dataframe[ortho_ani_condition]
        complement_ortho_ani_dataframe = ortho_ani_dataframe[~ortho_ani_condition]

        if len(filtered_ortho_ani_dataframe) == 0:
            print("Computing OrthoANI values ...")
            ortho_ani_vals = compute_ortho_ani_parallel(checked_genome_files,checked_genome_files_off1)
            print("Computed OrthoANI values")
        else:
            print("Using previously computed OrthoANI values")
            ortho_ani_vals = filtered_ortho_ani_dataframe["orthoani_val"]

        computed_ortho_ani_dataframe = pd.DataFrame(
            {
                "analysis_type": analysis_type,
                "analysis_data_dir": analysis_data_dir,
                "genome_file_1": checked_genome_files[:-1],
                "genome_file_2": checked_genome_files_off1,
                "orthoani_val": ortho_ani_vals
            }
        )
        ortho_ani_dataframe = pd.concat([complement_ortho_ani_dataframe,computed_ortho_ani_dataframe])

        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]
        
        for kmer_length in range(min_kmer_length,max_kmer_length+1):
            for c_val in c_val_range:
                canon = True

                iteration += 1

                print(f"ITERATION {iteration} : {kmer_length=}, {c_val=}, {canon=}")

                checked_genome_files_off1 = checked_genome_files[1:]

                kmer_sketch_ani_condition = (
                    (kmer_sketch_dataframe["genome_file_1"].isin(checked_genome_files)) &
                    (kmer_sketch_dataframe["kmer_length"] == kmer_length) &
                    (kmer_sketch_dataframe["c_val"] == c_val) &
                    (kmer_sketch_dataframe["canonical"] == canon)
                )

                filtered_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[kmer_sketch_ani_condition]
                complement_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[~kmer_sketch_ani_condition]

                if len(filtered_kmer_sketch_ani_dataframe) == 0:
                    polycond = generate_polycond(3,1000000007,c_val,iteration)
                    print("Computing sketches ...")
                    kmer_sketches = compute_kmer_sketches_parallel(
                        checked_genome_files,
                        kmer_length = kmer_length,
                        kmer_class = kmer_class,
                        sketching_cond = polycond,
                        canonical = canon
                    )
                    kmer_sketches_off1 = kmer_sketches[1:]
                    print("Sketching complete, computing ani ...")
                    kmer_ani_vals = compute_kmer_ani_parallel(kmer_sketches,kmer_sketches_off1)
                    print("ANI computation complete")
                else:
                    print("Using previously computed ANI values")
                    kmer_ani_vals = filtered_kmer_sketch_ani_dataframe["kmer_ani_val"]


                num_entries = len(kmer_ani_vals)
                
                computed_kmer_sketch_ani_dataframe = pd.DataFrame(
                    {
                        "analysis_type": analysis_type,
                        "analysis_data_dir": analysis_data_dir,
                        "genome_file_1": checked_genome_files[:-1],
                        "genome_file_2": checked_genome_files_off1,
                        "kmer_length": [kmer_length for _ in range(num_entries)],
                        "c_val": [c_val for _ in range(num_entries)],
                        "canonical": [canon for _ in range(num_entries)],
                        "kmer_ani_val": kmer_ani_vals
                    }
                )


                kmer_sketch_dataframe = pd.concat(
                    [complement_kmer_sketch_ani_dataframe,computed_kmer_sketch_ani_dataframe]
                )

                correlation_condition = (
                    (correlation_dataframe["analysis_type"] == analysis_type) &
                    (correlation_dataframe["analysis_data_dir"] == analysis_data_dir) &
                    (correlation_dataframe["kmer_length"] == kmer_length) &
                    (correlation_dataframe["c_val"] == c_val) & 
                    (correlation_dataframe["canonical"] == canon)
                )

                filtered_correlation_dataframe = correlation_dataframe[~correlation_condition] # remove to recompute

                print("Computing correlations...")


                # filtered_ortho_ani_dataframe = ortho_ani_dataframe[ortho_ani_condition]
                # filtered_kmer_sketch_ani_dataframe = kmer_sketch_dataframe[kmer_sketch_ani_condition]

                # combined_ani_dataframe = filtered_ortho_ani_dataframe.merge(filtered_kmer_sketch_ani_dataframe)


                # ortho_ani_vals = combined_ani_dataframe["orthoani_val"]
                # kmer_ani_vals = combined_ani_dataframe["kmer_ani_val"]

                
                filter_o, filter_k = zip(*[(o,k) for o,k in zip(ortho_ani_vals,kmer_ani_vals) if (k > 0 and o > 0)])

                dropped_zeros = len(ortho_ani_vals) - len(filter_o)
                pearson_coeff = scipy.stats.pearsonr(filter_o,filter_k)
                spearman_coeff = scipy.stats.spearmanr(filter_o,filter_k)

                lin_fit = np.poly1d(np.polyfit(filter_o, filter_k, 1))
                r2_val_raw = r2_score(filter_o,filter_k)
                r2_val_lin = r2_score(filter_o,[lin_fit(o) for o in filter_o])



                correlation_dataframe = pd.concat([filtered_correlation_dataframe,
                    pd.DataFrame({
                        "analysis_type": analysis_type,
                        "analysis_data_dir": analysis_data_dir,
                        "kmer_length": [kmer_length],
                        "c_val": [c_val],
                        "canonical": [canon],
                        "pearson_coeff" : [pearson_coeff.statistic],
                        "pearson_coeff_pval" : [pearson_coeff.pvalue],
                        "spearman_coeff" : [spearman_coeff.statistic],
                        "spearman_coeff_pval" : [spearman_coeff.pvalue],
                        "r2_val_raw": [r2_val_raw],
                        "r2_val_lin": [r2_val_lin],
                        "dropped_zeros": dropped_zeros
                    })],
                )
# Out:
# analysis_type='Single-Genus', analysis_data_dir='Pectobacterium'
# Using genome files ['../../data_temp/Single-Genus/Pectobacterium/64.fna', '../../data_temp/Single-Genus/Pectobacterium/32.fna', '../../data_temp/Single-Genus/Pectobacterium/99.fna', '../../data_temp/Single-Genus/Pectobacterium/43.fna', '../../data_temp/Single-Genus/Pectobacterium/7.fna', '../../data_temp/Single-Genus/Pectobacterium/98.fna', '../../data_temp/Single-Genus/Pectobacterium/58.fna', '../../data_temp/Single-Genus/Pectobacterium/90.fna', '../../data_temp/Single-Genus/Pectobacterium/14.fna', '../../data_temp/Single-Genus/Pectobacterium/41.fna', '../../data_temp/Single-Genus/Pectobacterium/67.fna', '../../data_temp/Single-Genus/Pectobacterium/73.fna', '../../data_temp/Single-Genus/Pectobacterium/17.fna', '../../data_temp/Single-Genus/Pectobacterium/56.fna', '../../data_temp/Single-Genus/Pectobacterium/50.fna', '../../data_temp/Single-Genus/Pectobacterium/2.fna', '../../data_temp/Single-Genus/Pectobacterium/46.fna', '../../data_temp/Single-Genus/Pectobacterium/52.fna', '../../data_temp/Single-Genus/Pectobacterium/65.fna', '../../data_temp/Single-Genus/Pectobacterium/95.fna', '../../data_temp/Single-Genus/Pectobacterium/45.fna', '../../data_temp/Single-Genus/Pectobacterium/74.fna', '../../data_temp/Single-Genus/Pectobacterium/44.fna', '../../data_temp/Single-Genus/Pectobacterium/12.fna', '../../data_temp/Single-Genus/Pectobacterium/94.fna', '../../data_temp/Single-Genus/Pectobacterium/25.fna', '../../data_temp/Single-Genus/Pectobacterium/60.fna', '../../data_temp/Single-Genus/Pectobacterium/39.fna', '../../data_temp/Single-Genus/Pectobacterium/22.fna', '../../data_temp/Single-Genus/Pectobacterium/48.fna', '../../data_temp/Single-Genus/Pectobacterium/88.fna', '../../data_temp/Single-Genus/Pectobacterium/24.fna', '../../data_temp/Single-Genus/Pectobacterium/9.fna', '../../data_temp/Single-Genus/Pectobacterium/86.fna', '../../data_temp/Single-Genus/Pectobacterium/5.fna', '../../data_temp/Single-Genus/Pectobacterium/89.fna', '../../data_temp/Single-Genus/Pectobacterium/71.fna', '../../data_temp/Single-Genus/Pectobacterium/54.fna', '../../data_temp/Single-Genus/Pectobacterium/23.fna', '../../data_temp/Single-Genus/Pectobacterium/49.fna', '../../data_temp/Single-Genus/Pectobacterium/40.fna', '../../data_temp/Single-Genus/Pectobacterium/18.fna', '../../data_temp/Single-Genus/Pectobacterium/4.fna', '../../data_temp/Single-Genus/Pectobacterium/20.fna', '../../data_temp/Single-Genus/Pectobacterium/63.fna', '../../data_temp/Single-Genus/Pectobacterium/33.fna', '../../data_temp/Single-Genus/Pectobacterium/87.fna', '../../data_temp/Single-Genus/Pectobacterium/80.fna', '../../data_temp/Single-Genus/Pectobacterium/26.fna', '../../data_temp/Single-Genus/Pectobacterium/1.fna', '../../data_temp/Single-Genus/Pectobacterium/47.fna', '../../data_temp/Single-Genus/Pectobacterium/92.fna', '../../data_temp/Single-Genus/Pectobacterium/51.fna', '../../data_temp/Single-Genus/Pectobacterium/37.fna', '../../data_temp/Single-Genus/Pectobacterium/84.fna', '../../data_temp/Single-Genus/Pectobacterium/53.fna', '../../data_temp/Single-Genus/Pectobacterium/70.fna', '../../data_temp/Single-Genus/Pectobacterium/42.fna', '../../data_temp/Single-Genus/Pectobacterium/57.fna', '../../data_temp/Single-Genus/Pectobacterium/72.fna', '../../data_temp/Single-Genus/Pectobacterium/91.fna', '../../data_temp/Single-Genus/Pectobacterium/27.fna', '../../data_temp/Single-Genus/Pectobacterium/19.fna', '../../data_temp/Single-Genus/Pectobacterium/66.fna', '../../data_temp/Single-Genus/Pectobacterium/13.fna', '../../data_temp/Single-Genus/Pectobacterium/16.fna', '../../data_temp/Single-Genus/Pectobacterium/29.fna', '../../data_temp/Single-Genus/Pectobacterium/8.fna', '../../data_temp/Single-Genus/Pectobacterium/21.fna', '../../data_temp/Single-Genus/Pectobacterium/3.fna', '../../data_temp/Single-Genus/Pectobacterium/10.fna', '../../data_temp/Single-Genus/Pectobacterium/30.fna', '../../data_temp/Single-Genus/Pectobacterium/38.fna', '../../data_temp/Single-Genus/Pectobacterium/9 ...
# Using previously computed OrthoANI values
# ITERATION 1 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 2 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 3 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 4 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 5 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 6 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 7 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 8 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 9 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 10 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 11 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 12 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 13 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 14 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 15 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 16 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 17 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 18 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 19 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 20 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 21 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 22 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 23 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 24 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 25 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 26 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Genus', analysis_data_dir='Morganella'
# Using genome files ['../../data_temp/Single-Genus/Morganella/64.fna', '../../data_temp/Single-Genus/Morganella/32.fna', '../../data_temp/Single-Genus/Morganella/99.fna', '../../data_temp/Single-Genus/Morganella/43.fna', '../../data_temp/Single-Genus/Morganella/7.fna', '../../data_temp/Single-Genus/Morganella/98.fna', '../../data_temp/Single-Genus/Morganella/58.fna', '../../data_temp/Single-Genus/Morganella/90.fna', '../../data_temp/Single-Genus/Morganella/14.fna', '../../data_temp/Single-Genus/Morganella/41.fna', '../../data_temp/Single-Genus/Morganella/67.fna', '../../data_temp/Single-Genus/Morganella/73.fna', '../../data_temp/Single-Genus/Morganella/17.fna', '../../data_temp/Single-Genus/Morganella/56.fna', '../../data_temp/Single-Genus/Morganella/50.fna', '../../data_temp/Single-Genus/Morganella/2.fna', '../../data_temp/Single-Genus/Morganella/46.fna', '../../data_temp/Single-Genus/Morganella/52.fna', '../../data_temp/Single-Genus/Morganella/65.fna', '../../data_temp/Single-Genus/Morganella/95.fna', '../../data_temp/Single-Genus/Morganella/45.fna', '../../data_temp/Single-Genus/Morganella/74.fna', '../../data_temp/Single-Genus/Morganella/44.fna', '../../data_temp/Single-Genus/Morganella/12.fna', '../../data_temp/Single-Genus/Morganella/94.fna', '../../data_temp/Single-Genus/Morganella/25.fna', '../../data_temp/Single-Genus/Morganella/60.fna', '../../data_temp/Single-Genus/Morganella/39.fna', '../../data_temp/Single-Genus/Morganella/22.fna', '../../data_temp/Single-Genus/Morganella/48.fna', '../../data_temp/Single-Genus/Morganella/88.fna', '../../data_temp/Single-Genus/Morganella/24.fna', '../../data_temp/Single-Genus/Morganella/9.fna', '../../data_temp/Single-Genus/Morganella/86.fna', '../../data_temp/Single-Genus/Morganella/5.fna', '../../data_temp/Single-Genus/Morganella/89.fna', '../../data_temp/Single-Genus/Morganella/71.fna', '../../data_temp/Single-Genus/Morganella/54.fna', '../../data_temp/Single-Genus/Morganella/23.fna', '../../data_temp/Single-Genus/Morganella/49.fna', '../../data_temp/Single-Genus/Morganella/40.fna', '../../data_temp/Single-Genus/Morganella/18.fna', '../../data_temp/Single-Genus/Morganella/4.fna', '../../data_temp/Single-Genus/Morganella/20.fna', '../../data_temp/Single-Genus/Morganella/63.fna', '../../data_temp/Single-Genus/Morganella/33.fna', '../../data_temp/Single-Genus/Morganella/87.fna', '../../data_temp/Single-Genus/Morganella/80.fna', '../../data_temp/Single-Genus/Morganella/26.fna', '../../data_temp/Single-Genus/Morganella/1.fna', '../../data_temp/Single-Genus/Morganella/47.fna', '../../data_temp/Single-Genus/Morganella/92.fna', '../../data_temp/Single-Genus/Morganella/51.fna', '../../data_temp/Single-Genus/Morganella/37.fna', '../../data_temp/Single-Genus/Morganella/84.fna', '../../data_temp/Single-Genus/Morganella/53.fna', '../../data_temp/Single-Genus/Morganella/70.fna', '../../data_temp/Single-Genus/Morganella/42.fna', '../../data_temp/Single-Genus/Morganella/57.fna', '../../data_temp/Single-Genus/Morganella/72.fna', '../../data_temp/Single-Genus/Morganella/91.fna', '../../data_temp/Single-Genus/Morganella/27.fna', '../../data_temp/Single-Genus/Morganella/19.fna', '../../data_temp/Single-Genus/Morganella/66.fna', '../../data_temp/Single-Genus/Morganella/13.fna', '../../data_temp/Single-Genus/Morganella/16.fna', '../../data_temp/Single-Genus/Morganella/29.fna', '../../data_temp/Single-Genus/Morganella/8.fna', '../../data_temp/Single-Genus/Morganella/21.fna', '../../data_temp/Single-Genus/Morganella/3.fna', '../../data_temp/Single-Genus/Morganella/10.fna', '../../data_temp/Single-Genus/Morganella/30.fna', '../../data_temp/Single-Genus/Morganella/38.fna', '../../data_temp/Single-Genus/Morganella/93.fna', '../../data_temp/Single-Genus/Morganella/78.fna', '../../data_temp/Single-Genus/Morganella/77.fna', '../../data_temp/Single-Genus/Morganella/75.fna', '../../data_temp/Single-Genus/Morganella/35.fna', '../../data_temp/Single-Genus/Morganella/31.fna', '../../data_temp/Single-Genus/Morganel ...
# Using previously computed OrthoANI values
# ITERATION 27 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 28 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 29 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 30 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 31 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 32 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 33 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 34 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 35 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 36 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 37 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 38 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 39 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 40 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 41 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 42 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 43 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 44 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 45 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 46 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 47 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 48 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 49 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 50 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 51 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 52 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Genus', analysis_data_dir='Xylella'
# Using genome files ['../../data_temp/Single-Genus/Xylella/64.fna', '../../data_temp/Single-Genus/Xylella/32.fna', '../../data_temp/Single-Genus/Xylella/99.fna', '../../data_temp/Single-Genus/Xylella/43.fna', '../../data_temp/Single-Genus/Xylella/7.fna', '../../data_temp/Single-Genus/Xylella/98.fna', '../../data_temp/Single-Genus/Xylella/58.fna', '../../data_temp/Single-Genus/Xylella/90.fna', '../../data_temp/Single-Genus/Xylella/14.fna', '../../data_temp/Single-Genus/Xylella/41.fna', '../../data_temp/Single-Genus/Xylella/67.fna', '../../data_temp/Single-Genus/Xylella/73.fna', '../../data_temp/Single-Genus/Xylella/17.fna', '../../data_temp/Single-Genus/Xylella/56.fna', '../../data_temp/Single-Genus/Xylella/50.fna', '../../data_temp/Single-Genus/Xylella/2.fna', '../../data_temp/Single-Genus/Xylella/46.fna', '../../data_temp/Single-Genus/Xylella/52.fna', '../../data_temp/Single-Genus/Xylella/65.fna', '../../data_temp/Single-Genus/Xylella/95.fna', '../../data_temp/Single-Genus/Xylella/45.fna', '../../data_temp/Single-Genus/Xylella/74.fna', '../../data_temp/Single-Genus/Xylella/44.fna', '../../data_temp/Single-Genus/Xylella/12.fna', '../../data_temp/Single-Genus/Xylella/94.fna', '../../data_temp/Single-Genus/Xylella/25.fna', '../../data_temp/Single-Genus/Xylella/60.fna', '../../data_temp/Single-Genus/Xylella/39.fna', '../../data_temp/Single-Genus/Xylella/22.fna', '../../data_temp/Single-Genus/Xylella/48.fna', '../../data_temp/Single-Genus/Xylella/88.fna', '../../data_temp/Single-Genus/Xylella/24.fna', '../../data_temp/Single-Genus/Xylella/9.fna', '../../data_temp/Single-Genus/Xylella/86.fna', '../../data_temp/Single-Genus/Xylella/5.fna', '../../data_temp/Single-Genus/Xylella/89.fna', '../../data_temp/Single-Genus/Xylella/71.fna', '../../data_temp/Single-Genus/Xylella/54.fna', '../../data_temp/Single-Genus/Xylella/23.fna', '../../data_temp/Single-Genus/Xylella/49.fna', '../../data_temp/Single-Genus/Xylella/40.fna', '../../data_temp/Single-Genus/Xylella/18.fna', '../../data_temp/Single-Genus/Xylella/4.fna', '../../data_temp/Single-Genus/Xylella/20.fna', '../../data_temp/Single-Genus/Xylella/63.fna', '../../data_temp/Single-Genus/Xylella/33.fna', '../../data_temp/Single-Genus/Xylella/87.fna', '../../data_temp/Single-Genus/Xylella/80.fna', '../../data_temp/Single-Genus/Xylella/26.fna', '../../data_temp/Single-Genus/Xylella/1.fna', '../../data_temp/Single-Genus/Xylella/47.fna', '../../data_temp/Single-Genus/Xylella/92.fna', '../../data_temp/Single-Genus/Xylella/51.fna', '../../data_temp/Single-Genus/Xylella/37.fna', '../../data_temp/Single-Genus/Xylella/84.fna', '../../data_temp/Single-Genus/Xylella/53.fna', '../../data_temp/Single-Genus/Xylella/70.fna', '../../data_temp/Single-Genus/Xylella/42.fna', '../../data_temp/Single-Genus/Xylella/57.fna', '../../data_temp/Single-Genus/Xylella/72.fna', '../../data_temp/Single-Genus/Xylella/91.fna', '../../data_temp/Single-Genus/Xylella/27.fna', '../../data_temp/Single-Genus/Xylella/19.fna', '../../data_temp/Single-Genus/Xylella/66.fna', '../../data_temp/Single-Genus/Xylella/13.fna', '../../data_temp/Single-Genus/Xylella/16.fna', '../../data_temp/Single-Genus/Xylella/29.fna', '../../data_temp/Single-Genus/Xylella/8.fna', '../../data_temp/Single-Genus/Xylella/21.fna', '../../data_temp/Single-Genus/Xylella/3.fna', '../../data_temp/Single-Genus/Xylella/10.fna', '../../data_temp/Single-Genus/Xylella/30.fna', '../../data_temp/Single-Genus/Xylella/38.fna', '../../data_temp/Single-Genus/Xylella/93.fna', '../../data_temp/Single-Genus/Xylella/78.fna', '../../data_temp/Single-Genus/Xylella/77.fna', '../../data_temp/Single-Genus/Xylella/75.fna', '../../data_temp/Single-Genus/Xylella/35.fna', '../../data_temp/Single-Genus/Xylella/31.fna', '../../data_temp/Single-Genus/Xylella/28.fna', '../../data_temp/Single-Genus/Xylella/82.fna', '../../data_temp/Single-Genus/Xylella/59.fna', '../../data_temp/Single-Genus/Xylella/69.fna', '../../data_temp/Single-Genus/Xylella/62.fna', '../../data_temp/Single-Genus/Xylella/85 ...
# Using previously computed OrthoANI values
# ITERATION 53 : kmer_length=10, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 54 : kmer_length=11, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 55 : kmer_length=12, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 56 : kmer_length=13, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 57 : kmer_length=14, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 58 : kmer_length=15, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 59 : kmer_length=16, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 60 : kmer_length=17, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 61 : kmer_length=18, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 62 : kmer_length=19, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 63 : kmer_length=20, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 64 : kmer_length=21, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 65 : kmer_length=22, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 66 : kmer_length=23, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 67 : kmer_length=24, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 68 : kmer_length=25, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 69 : kmer_length=26, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 70 : kmer_length=27, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 71 : kmer_length=28, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 72 : kmer_length=29, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 73 : kmer_length=30, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 74 : kmer_length=31, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 75 : kmer_length=32, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 76 : kmer_length=33, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 77 : kmer_length=34, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# ITERATION 78 : kmer_length=35, c_val=200, canon=True
# Using previously computed ANI values
# Computing correlations...
# analysis_type='Single-Family', analysis_data_dir='Enterobacteriaceae'
# Using genome files ['../../data_temp/Single-Family/Enterobacteriaceae/479.fna', '../../data_temp/Single-Family/Enterobacteriaceae/306.fna', '../../data_temp/Single-Family/Enterobacteriaceae/228.fna', '../../data_temp/Single-Family/Enterobacteriaceae/404.fna', '../../data_temp/Single-Family/Enterobacteriaceae/112.fna', '../../data_temp/Single-Family/Enterobacteriaceae/164.fna', '../../data_temp/Single-Family/Enterobacteriaceae/429.fna', '../../data_temp/Single-Family/Enterobacteriaceae/367.fna', '../../data_temp/Single-Family/Enterobacteriaceae/64.fna', '../../data_temp/Single-Family/Enterobacteriaceae/491.fna', '../../data_temp/Single-Family/Enterobacteriaceae/236.fna', '../../data_temp/Single-Family/Enterobacteriaceae/130.fna', '../../data_temp/Single-Family/Enterobacteriaceae/281.fna', '../../data_temp/Single-Family/Enterobacteriaceae/287.fna', '../../data_temp/Single-Family/Enterobacteriaceae/413.fna', '../../data_temp/Single-Family/Enterobacteriaceae/300.fna', '../../data_temp/Single-Family/Enterobacteriaceae/252.fna', '../../data_temp/Single-Family/Enterobacteriaceae/140.fna', '../../data_temp/Single-Family/Enterobacteriaceae/32.fna', '../../data_temp/Single-Family/Enterobacteriaceae/379.fna', '../../data_temp/Single-Family/Enterobacteriaceae/222.fna', '../../data_temp/Single-Family/Enterobacteriaceae/153.fna', '../../data_temp/Single-Family/Enterobacteriaceae/350.fna', '../../data_temp/Single-Family/Enterobacteriaceae/102.fna', '../../data_temp/Single-Family/Enterobacteriaceae/430.fna', '../../data_temp/Single-Family/Enterobacteriaceae/488.fna', '../../data_temp/Single-Family/Enterobacteriaceae/99.fna', '../../data_temp/Single-Family/Enterobacteriaceae/172.fna', '../../data_temp/Single-Family/Enterobacteriaceae/446.fna', '../../data_temp/Single-Family/Enterobacteriaceae/448.fna', '../../data_temp/Single-Family/Enterobacteriaceae/385.fna', '../../data_temp/Single-Family/Enterobacteriaceae/152.fna', '../../data_temp/Single-Family/Enterobacteriaceae/316.fna', '../../data_temp/Single-Family/Enterobacteriaceae/162.fna', '../../data_temp/Single-Family/Enterobacteriaceae/321.fna', '../../data_temp/Single-Family/Enterobacteriaceae/439.fna', '../../data_temp/Single-Family/Enterobacteriaceae/128.fna', '../../data_temp/Single-Family/Enterobacteriaceae/314.fna', '../../data_temp/Single-Family/Enterobacteriaceae/191.fna', '../../data_temp/Single-Family/Enterobacteriaceae/177.fna', '../../data_temp/Single-Family/Enterobacteriaceae/43.fna', '../../data_temp/Single-Family/Enterobacteriaceae/212.fna', '../../data_temp/Single-Family/Enterobacteriaceae/260.fna', '../../data_temp/Single-Family/Enterobacteriaceae/452.fna', '../../data_temp/Single-Family/Enterobacteriaceae/315.fna', '../../data_temp/Single-Family/Enterobacteriaceae/421.fna', '../../data_temp/Single-Family/Enterobacteriaceae/384.fna', '../../data_temp/Single-Family/Enterobacteriaceae/7.fna', '../../data_temp/Single-Family/Enterobacteriaceae/98.fna', '../../data_temp/Single-Family/Enterobacteriaceae/213.fna', '../../data_temp/Single-Family/Enterobacteriaceae/58.fna', '../../data_temp/Single-Family/Enterobacteriaceae/425.fna', '../../data_temp/Single-Family/Enterobacteriaceae/392.fna', '../../data_temp/Single-Family/Enterobacteriaceae/493.fna', '../../data_temp/Single-Family/Enterobacteriaceae/283.fna', '../../data_temp/Single-Family/Enterobacteriaceae/90.fna', '../../data_temp/Single-Family/Enterobacteriaceae/473.fna', '../../data_temp/Single-Family/Enterobacteriaceae/440.fna', '../../data_temp/Single-Family/Enterobacteriaceae/147.fna', '../../data_temp/Single-Family/Enterobacteriaceae/133.fna', '../../data_temp/Single-Family/Enterobacteriaceae/168.fna', '../../data_temp/Single-Family/Enterobacteriaceae/266.fna', '../../data_temp/Single-Family/Enterobacteriaceae/149.fna', '../../data_temp/Single-Family/Enterobacteriaceae/221.fna', '../../data_temp/Single-Family/Enterobacteriaceae/151.fna', '../../data_temp/Single-Family/Enterobacteriaceae/141.fna', '../../data_temp/Single-Famil ...
# Using previously computed OrthoANI values
# ITERATION 79 : kmer_length=10, c_val=200, canon=True
# Computing sketches ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 64
#      62 polycond = generate_polycond(3,1000000007,c_val,iteration)
#      63 print("Computing sketches ...")
# ---> 64 kmer_sketches = compute_kmer_sketches_parallel(
#      65     checked_genome_files,
#      66     kmer_length = kmer_length,
#      67     kmer_class = kmer_class,
#      68     sketching_cond = polycond,
#      69     canonical = canon
#      70 )
#      71 kmer_sketches_off1 = kmer_sketches[1:]
#      72 print("Sketching complete, computing ani ...")
#
# Cell In[12], line 9, in compute_kmer_sketches_parallel(genome_files, kmer_length, kmer_class, sketching_cond, canonical)
#       7 args = [(g,kmer_class,sketching_cond,kmer_length,canonical) for g in genome_files]
#       8 with Pool(max_pool) as p:
# ----> 9     return p.starmap(compute_kmer_sketches,args)
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
print(ortho_ani_dataframe)

# %%
print(kmer_sketch_dataframe)

# %%
print(correlation_dataframe)

# %%
ortho_ani_dataframe.to_csv(ortho_ani_filename)
kmer_sketch_dataframe.to_csv(kmer_sketch_ani_filename)
correlation_dataframe.to_csv(corrleation_filename)

# %%
def box_plot_OrthoANI(
    analysis_type, 
    ortho_ani_dataframe
):
    plt.figure(figsize=(20,10),dpi=300)
    
    plt.title(f"Box Plot of OrthoANI values for {analysis_type}")
    
    
    filtered_ortho_ani_df = ortho_ani_dataframe[ortho_ani_dataframe["analysis_type"] == analysis_type]

    plt.boxplot(
        [filtered_ortho_ani_df[filtered_ortho_ani_df["analysis_data_dir"] == analysis_data_dir]["orthoani_val"] for analysis_data_dir in analysis_types[analysis_type]],
        labels=[analysis_data_dir for analysis_data_dir in analysis_types[analysis_type]],
    )
    plt.ylabel("OrthoAni Value")

    plt.savefig(f"../../plots/correlations/{analysis_type}-OrthoANI-boxplot.png")
    plt.close()

# %%
def plot_correlation(
        analysis_type, 
        correlation_dataframe,
        c_val_range,
        correlation_string,
    ):

    

    plt.figure(figsize=(10,10),dpi=300)
    plt.xlabel("K-mer Length")
    plt.ylabel(correlation_string)
    plt.title(f"{correlation_string} of {kmer_class.__name__} ANI Esimtation against K-mer Length on {analysis_type}") 
    for analysis_data_dir in analysis_types[analysis_type]:
        analysis_correlation_dataframe = correlation_dataframe[
            (correlation_dataframe["analysis_type"] == analysis_type) 
            & (correlation_dataframe["analysis_data_dir"] == analysis_data_dir)
        ]
        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]
        kmer_lengths = [kmer_length for kmer_length in range(min_kmer_length,max_kmer_length+1)]
        canonical = True

        filtered_correlation_dataframe = analysis_correlation_dataframe[
            analysis_correlation_dataframe["canonical"] == canonical
        ]
        
        
        for c_val in c_val_range:
            correlation = list(
                filtered_correlation_dataframe[
                    (filtered_correlation_dataframe["c_val"] == c_val) &
                    (filtered_correlation_dataframe["kmer_length"].isin(set(kmer_lengths)))
                ][correlation_string]
            )
            print(len(kmer_lengths))
            print(len(correlation))
            # plt.scatter(kmer_lengths,correlation,label=f"{analysis_data_dir}",s=[3 for _ in range(len(kmer_lengths))])
            plt.plot(kmer_lengths,correlation,label=f"{analysis_data_dir}")

    plt.legend()
    plt.plot()
    plt.savefig(f"../../plots/correlations/{analysis_type}-{kmer_class.__name__}-{canonical=}-{correlation_string}.png")
    plt.close()

# %%
for analysis_type in analysis_types:
    for correlation_string in ["pearson_coeff","spearman_coeff","r2_val_raw","r2_val_lin","dropped_zeros"]:
        plot_correlation(
            analysis_type=analysis_type,
            correlation_dataframe=correlation_dataframe,
            c_val_range=c_val_range,
            correlation_string=correlation_string
        )
    
    box_plot_OrthoANI(
        analysis_type=analysis_type,
        ortho_ani_dataframe=ortho_ani_dataframe
    )

    # analysis_correlation_dataframe = correlation_dataframe[
    #     (correlation_dataframe["analysis_type"] == analysis_type) &
    #     (correlation_dataframe["analysis_data_dir"] == analysis_data_dir)
    # ]

    # for canonical in (True,):
    #     filtered_correlation_dataframe = analysis_correlation_dataframe[
    #         analysis_correlation_dataframe["canonical"] == canonical
    #     ]
    #     plt.figure(figsize=(10,10),dpi=300)
    #     plt.xlabel("K-mer Length")
    #     plt.ylabel("Pearson Correlation")
    #     plt.title("Pearson Correlation of FracMinHash ANI Esimtation against K-mer Length at different c-value thresholds")

    #     for c_val in c_val_range:
    #         pearson_correlation = list(
    #             filtered_correlation_dataframe[
    #                 (filtered_correlation_dataframe["c_val"] == c_val) &
    #                 (filtered_correlation_dataframe["kmer_length"].isin(set(range(min_kmer_length,max_kmer_length+1))))
    #             ]["pearson_coeff"]
    #         )
    #         print(len(kmer_lengths))
    #         print(len(pearson_correlation))
    #         plt.scatter(kmer_lengths,pearson_correlation,label=f"c = {c_val}")

    #     plt.legend()
    #     plt.plot()
    #     plt.savefig(f"../../plots/correlations/{analysis_type}-{analysis_data_dir}-{kmer_class.__name__}-{canonical=}-pearson.png")
    #     plt.close()




    #     plt.figure(figsize=(10,10),dpi=300)
    #     plt.xlabel("K-mer Length")
    #     plt.ylabel("Spearman Correlation")
    #     plt.title("Spearman Correlation of FracMinHash ANI Esimtation against K-mer Length at different c-value thresholds")

    #     for c_val in c_val_range:
    #         spearman_correlation = [ 
    #             filtered_correlation_dataframe[
    #                 (filtered_correlation_dataframe["c_val"] == c_val) &
    #                 (filtered_correlation_dataframe["kmer_length"] == kmer_length)
    #             ]["spearman_coeff"]
    #             for kmer_length in range(min_kmer_length,max_kmer_length+1)
    #         ]
    #         print(kmer_lengths)
    #         print(spearman_correlation)
    #         plt.scatter(kmer_lengths,spearman_correlation,label=f"c = {c_val}")

    #     plt.legend()
    #     plt.plot()
    #     plt.savefig(f"../../plots/correlations/{analysis_type}-{analysis_data_dir}-{kmer_class.__name__}-{canonical=}-spearman.png")
    #     plt.close()

# %%
import imageio

def plot_single_kmer(
        ortho_vals_df,
        kmer_vals_df,
        kmer_length,
):
    
    Path(f"../../plots/temp/{analysis_type}-{analysis_data_dir}/").mkdir(parents=True, exist_ok=True)
    combined_df = pd.merge(ortho_vals_df,kmer_vals_df)
    ortho_vals = combined_df["orthoani_val"]
    kmer_vals = combined_df["kmer_ani_val"]
    fig = plt.figure(figsize=(10,10),dpi=300)
    ax = fig.add_subplot()
    filter_o, filter_k = zip(*[(o,k) for o,k in zip(ortho_vals,kmer_vals) if (k > 0 and o > 0)])
    lin_fit = np.poly1d(np.polyfit(filter_o, filter_k, 1))
    ax.plot(filter_o,filter_o,"r-")
    ax.scatter(filter_o,filter_k,marker="^",s=[2 for _ in filter_o])
    # ax.scatter(filter_o,filter_o,marker="o",s=[2 for _ in filter_o])
    ax.plot(np.unique(filter_o), lin_fit(np.unique(filter_o)))
    plt.figtext(0.7,0.15,f"Zeros dropped : {len(ortho_vals) - len(filter_o)}")
    pearson_coeff = scipy.stats.pearsonr(filter_o,filter_k)

    plt.figtext(0.7,0.17,f"Pearson Corr. Coeff.: {pearson_coeff.statistic:.3f}")
    plt.figtext(0.7,0.19,f"Pearson Corr. p.: {pearson_coeff.pvalue:.3e}")



    ax.legend(["OrthoANI",f"{kmer_length}-mer dots",f"{kmer_length}-mer line : {lin_fit}"])

    plotname = f"../../plots/temp/{analysis_type}-{analysis_data_dir}/{analysis_type}-{analysis_data_dir}-{kmer_length}mer-estimated-ANI.png"
    plt.savefig(plotname)
    plt.close()
    return plotname

# %%
for analysis_type in analysis_types:
    for analysis_data_dir in analysis_types[analysis_type]:
        Path(f"../../plots/{analysis_type}-{analysis_data_dir}/").mkdir(parents=True, exist_ok=True)

        analysis_images = []
        min_kmer_length, max_kmer_length = analysis_types[analysis_type][analysis_data_dir]

        for kmer_length in range(min_kmer_length,max_kmer_length+1):
            for c_val in c_val_range:
                canon = True
                analysis_images.append(
                    imageio.v3.imread(
                        plot_single_kmer(
                            ortho_vals_df = ortho_ani_dataframe[
                                (ortho_ani_dataframe["analysis_type"] == analysis_type)
                                & (ortho_ani_dataframe["analysis_data_dir"] == analysis_data_dir)
                            ],
                            kmer_vals_df = kmer_sketch_dataframe[
                                (kmer_sketch_dataframe["analysis_type"] == analysis_type)
                                & (kmer_sketch_dataframe["analysis_data_dir"] == analysis_data_dir)
                                & (kmer_sketch_dataframe["kmer_length"] == kmer_length)
                                & (kmer_sketch_dataframe["c_val"] == c_val)
                                & (kmer_sketch_dataframe["canonical"] == canon)
                            ],
                            kmer_length= kmer_length,
                        )
                    )
                )
        
        print(len(analysis_images))
        plot_gif_filename = f"../../plots/{analysis_type}-{analysis_data_dir}/{analysis_type}-{analysis_data_dir}-estimated-ANI.gif"
        imageio.mimsave(plot_gif_filename,analysis_images,duration=0.5)
