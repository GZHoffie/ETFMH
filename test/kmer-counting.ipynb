# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import sys
import os
import scipy
import math
from sklearn.metrics import r2_score
from pathlib import Path
import subprocess
import pandas as pd

from Bio.SeqIO import read, parse
import orthoani

from multiprocess import Pool

max_pool = 16
lim_file = 200

sys.path.append('../')
sys.path.append('../../')

# %%
from db_sketching.kmer_set import KMerSet, FracMinHash, TruncatedKMerSet, MeanFracMinHash

# %%
# analysis_type = "Single-Species"
# analysis_data_dir = "Escherichia coli" 
# analysis_data_dir = "Yersinia pestis" 

# analysis_type = "Single-Genus"
# analysis_data_dir = "Yersinia" 
# analysis_data_dir = "Salmonella"

# %%
data_dir = "../../data_temp"
genome_files = []

for collection_type in os.listdir(data_dir):
    collection_type_path = os.path.join(data_dir,collection_type)
    for collection in os.listdir(collection_type_path):
        collection_path = os.path.join(collection_type_path,collection)
        for filename in os.listdir(collection_path):
            full_filename = os.path.join(collection_path,filename)
            genome_files.append(full_filename)


print(genome_files)
print(len(genome_files))
# Out:
# ['../../data_temp/Single-Species/Erwinia amylovora/64.fna', '../../data_temp/Single-Species/Erwinia amylovora/32.fna', '../../data_temp/Single-Species/Erwinia amylovora/99.fna', '../../data_temp/Single-Species/Erwinia amylovora/43.fna', '../../data_temp/Single-Species/Erwinia amylovora/7.fna', '../../data_temp/Single-Species/Erwinia amylovora/98.fna', '../../data_temp/Single-Species/Erwinia amylovora/58.fna', '../../data_temp/Single-Species/Erwinia amylovora/90.fna', '../../data_temp/Single-Species/Erwinia amylovora/14.fna', '../../data_temp/Single-Species/Erwinia amylovora/41.fna', '../../data_temp/Single-Species/Erwinia amylovora/67.fna', '../../data_temp/Single-Species/Erwinia amylovora/73.fna', '../../data_temp/Single-Species/Erwinia amylovora/17.fna', '../../data_temp/Single-Species/Erwinia amylovora/56.fna', '../../data_temp/Single-Species/Erwinia amylovora/50.fna', '../../data_temp/Single-Species/Erwinia amylovora/2.fna', '../../data_temp/Single-Species/Erwinia amylovora/46.fna', '../../data_temp/Single-Species/Erwinia amylovora/52.fna', '../../data_temp/Single-Species/Erwinia amylovora/65.fna', '../../data_temp/Single-Species/Erwinia amylovora/95.fna', '../../data_temp/Single-Species/Erwinia amylovora/45.fna', '../../data_temp/Single-Species/Erwinia amylovora/74.fna', '../../data_temp/Single-Species/Erwinia amylovora/44.fna', '../../data_temp/Single-Species/Erwinia amylovora/12.fna', '../../data_temp/Single-Species/Erwinia amylovora/94.fna', '../../data_temp/Single-Species/Erwinia amylovora/25.fna', '../../data_temp/Single-Species/Erwinia amylovora/60.fna', '../../data_temp/Single-Species/Erwinia amylovora/39.fna', '../../data_temp/Single-Species/Erwinia amylovora/22.fna', '../../data_temp/Single-Species/Erwinia amylovora/48.fna', '../../data_temp/Single-Species/Erwinia amylovora/88.fna', '../../data_temp/Single-Species/Erwinia amylovora/24.fna', '../../data_temp/Single-Species/Erwinia amylovora/9.fna', '../../data_temp/Single-Species/Erwinia amylovora/86.fna', '../../data_temp/Single-Species/Erwinia amylovora/5.fna', '../../data_temp/Single-Species/Erwinia amylovora/89.fna', '../../data_temp/Single-Species/Erwinia amylovora/71.fna', '../../data_temp/Single-Species/Erwinia amylovora/54.fna', '../../data_temp/Single-Species/Erwinia amylovora/23.fna', '../../data_temp/Single-Species/Erwinia amylovora/49.fna', '../../data_temp/Single-Species/Erwinia amylovora/40.fna', '../../data_temp/Single-Species/Erwinia amylovora/18.fna', '../../data_temp/Single-Species/Erwinia amylovora/4.fna', '../../data_temp/Single-Species/Erwinia amylovora/20.fna', '../../data_temp/Single-Species/Erwinia amylovora/63.fna', '../../data_temp/Single-Species/Erwinia amylovora/33.fna', '../../data_temp/Single-Species/Erwinia amylovora/87.fna', '../../data_temp/Single-Species/Erwinia amylovora/80.fna', '../../data_temp/Single-Species/Erwinia amylovora/26.fna', '../../data_temp/Single-Species/Erwinia amylovora/1.fna', '../../data_temp/Single-Species/Erwinia amylovora/47.fna', '../../data_temp/Single-Species/Erwinia amylovora/92.fna', '../../data_temp/Single-Species/Erwinia amylovora/51.fna', '../../data_temp/Single-Species/Erwinia amylovora/37.fna', '../../data_temp/Single-Species/Erwinia amylovora/84.fna', '../../data_temp/Single-Species/Erwinia amylovora/53.fna', '../../data_temp/Single-Species/Erwinia amylovora/70.fna', '../../data_temp/Single-Species/Erwinia amylovora/42.fna', '../../data_temp/Single-Species/Erwinia amylovora/57.fna', '../../data_temp/Single-Species/Erwinia amylovora/72.fna', '../../data_temp/Single-Species/Erwinia amylovora/91.fna', '../../data_temp/Single-Species/Erwinia amylovora/27.fna', '../../data_temp/Single-Species/Erwinia amylovora/19.fna', '../../data_temp/Single-Species/Erwinia amylovora/66.fna', '../../data_temp/Single-Species/Erwinia amylovora/13.fna', '../../data_temp/Single-Species/Erwinia amylovora/16.fna', '../../data_temp/Single-Species/Erwinia amylovora/29.fna', '../../data_temp/Single-Species/Erwinia amylovora/8. ...
# 5273

# %%
checked_genome_files = []
for file in genome_files:
    try:
        parsed_file = parse(file,"fasta")
        assert(len([record for record in parsed_file]) > 0)
        checked_genome_files.append(file)
    except:
        print(f"File {file} is damaged / invalid")
# Out:
# File ../../data_temp/Single-Species/Neisseria gonorrhoeae/485 is damaged / invalid
# File ../../data_temp/Single-Species/Corynebacterium pseudotuberculosis/25.fna is damaged / invalid
# File ../../data_temp/Single-Species/Klebsiella quasipneumoniae/48.fna is damaged / invalid
# File ../../data_temp/Single-Species/Xylella fastidiosa/73.zip is damaged / invalid
# File ../../data_temp/Single-Species/Xylella fastidiosa/73.fna is damaged / invalid
# File ../../data_temp/Single-Species/Xylella fastidiosa/README.md is damaged / invalid
# File ../../data_temp/Single-Species/Xylella fastidiosa/ncbi_dataset is damaged / invalid
# File ../../data_temp/Single-Species/Yersinia pestis/632 is damaged / invalid
# File ../../data_temp/Single-Species/Klebsiella variicola/203.fna is damaged / invalid
# File ../../data_temp/Single-Species/Escherichia coli/623 is damaged / invalid
# File ../../data_temp/Single-Species/Bordetella pertussis/520 is damaged / invalid
# File ../../data_temp/Single-Genus/Escherichia/29.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Haemophilus/57.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Ligilactobacillus/16.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Gilliamella/8.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Riemerella/3.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Lentilactobacillus/3.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Klebsiella/9.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Aeromonas/642 is damaged / invalid
# File ../../data_temp/Single-Genus/Phenylobacterium/20 is damaged / invalid
# File ../../data_temp/Single-Genus/Prevotella/README.md is damaged / invalid
# File ../../data_temp/Single-Genus/Prevotella/81.zip is damaged / invalid
# File ../../data_temp/Single-Genus/Prevotella/ncbi_dataset is damaged / invalid
# File ../../data_temp/Single-Genus/Prevotella/81.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Aggregatibacter/3.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Nitrosomonas/0.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Actinomarina/0.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Latilactobacillus/1.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Cutibacterium/1.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Levilactobacillus/13.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Elizabethkingia/7.fna is damaged / invalid
# File ../../data_temp/Single-Genus/Mycobacterium/48.fna is damaged / invalid

# %%
print(checked_genome_files)
print(len(checked_genome_files))
# Out:
# ['../../data_temp/Single-Species/Erwinia amylovora/64.fna', '../../data_temp/Single-Species/Erwinia amylovora/32.fna', '../../data_temp/Single-Species/Erwinia amylovora/99.fna', '../../data_temp/Single-Species/Erwinia amylovora/43.fna', '../../data_temp/Single-Species/Erwinia amylovora/7.fna', '../../data_temp/Single-Species/Erwinia amylovora/98.fna', '../../data_temp/Single-Species/Erwinia amylovora/58.fna', '../../data_temp/Single-Species/Erwinia amylovora/90.fna', '../../data_temp/Single-Species/Erwinia amylovora/14.fna', '../../data_temp/Single-Species/Erwinia amylovora/41.fna', '../../data_temp/Single-Species/Erwinia amylovora/67.fna', '../../data_temp/Single-Species/Erwinia amylovora/73.fna', '../../data_temp/Single-Species/Erwinia amylovora/17.fna', '../../data_temp/Single-Species/Erwinia amylovora/56.fna', '../../data_temp/Single-Species/Erwinia amylovora/50.fna', '../../data_temp/Single-Species/Erwinia amylovora/2.fna', '../../data_temp/Single-Species/Erwinia amylovora/46.fna', '../../data_temp/Single-Species/Erwinia amylovora/52.fna', '../../data_temp/Single-Species/Erwinia amylovora/65.fna', '../../data_temp/Single-Species/Erwinia amylovora/95.fna', '../../data_temp/Single-Species/Erwinia amylovora/45.fna', '../../data_temp/Single-Species/Erwinia amylovora/74.fna', '../../data_temp/Single-Species/Erwinia amylovora/44.fna', '../../data_temp/Single-Species/Erwinia amylovora/12.fna', '../../data_temp/Single-Species/Erwinia amylovora/94.fna', '../../data_temp/Single-Species/Erwinia amylovora/25.fna', '../../data_temp/Single-Species/Erwinia amylovora/60.fna', '../../data_temp/Single-Species/Erwinia amylovora/39.fna', '../../data_temp/Single-Species/Erwinia amylovora/22.fna', '../../data_temp/Single-Species/Erwinia amylovora/48.fna', '../../data_temp/Single-Species/Erwinia amylovora/88.fna', '../../data_temp/Single-Species/Erwinia amylovora/24.fna', '../../data_temp/Single-Species/Erwinia amylovora/9.fna', '../../data_temp/Single-Species/Erwinia amylovora/86.fna', '../../data_temp/Single-Species/Erwinia amylovora/5.fna', '../../data_temp/Single-Species/Erwinia amylovora/89.fna', '../../data_temp/Single-Species/Erwinia amylovora/71.fna', '../../data_temp/Single-Species/Erwinia amylovora/54.fna', '../../data_temp/Single-Species/Erwinia amylovora/23.fna', '../../data_temp/Single-Species/Erwinia amylovora/49.fna', '../../data_temp/Single-Species/Erwinia amylovora/40.fna', '../../data_temp/Single-Species/Erwinia amylovora/18.fna', '../../data_temp/Single-Species/Erwinia amylovora/4.fna', '../../data_temp/Single-Species/Erwinia amylovora/20.fna', '../../data_temp/Single-Species/Erwinia amylovora/63.fna', '../../data_temp/Single-Species/Erwinia amylovora/33.fna', '../../data_temp/Single-Species/Erwinia amylovora/87.fna', '../../data_temp/Single-Species/Erwinia amylovora/80.fna', '../../data_temp/Single-Species/Erwinia amylovora/26.fna', '../../data_temp/Single-Species/Erwinia amylovora/1.fna', '../../data_temp/Single-Species/Erwinia amylovora/47.fna', '../../data_temp/Single-Species/Erwinia amylovora/92.fna', '../../data_temp/Single-Species/Erwinia amylovora/51.fna', '../../data_temp/Single-Species/Erwinia amylovora/37.fna', '../../data_temp/Single-Species/Erwinia amylovora/84.fna', '../../data_temp/Single-Species/Erwinia amylovora/53.fna', '../../data_temp/Single-Species/Erwinia amylovora/70.fna', '../../data_temp/Single-Species/Erwinia amylovora/42.fna', '../../data_temp/Single-Species/Erwinia amylovora/57.fna', '../../data_temp/Single-Species/Erwinia amylovora/72.fna', '../../data_temp/Single-Species/Erwinia amylovora/91.fna', '../../data_temp/Single-Species/Erwinia amylovora/27.fna', '../../data_temp/Single-Species/Erwinia amylovora/19.fna', '../../data_temp/Single-Species/Erwinia amylovora/66.fna', '../../data_temp/Single-Species/Erwinia amylovora/13.fna', '../../data_temp/Single-Species/Erwinia amylovora/16.fna', '../../data_temp/Single-Species/Erwinia amylovora/29.fna', '../../data_temp/Single-Species/Erwinia amylovora/8. ...
# 5241

# %%
def get_genome_length(genome_file):
    genome_kmer = KMerSet(20)
    genome_kmer.insert_file(genome_file)
    return genome_kmer.length

def compute_length_parallel(genome_files):
    with Pool(max_pool) as p:
        return p.starmap(get_genome_length,([(g_file,) for g_file in genome_files]))

    
checked_genome_lengths = compute_length_parallel(checked_genome_files)
print(checked_genome_lengths)
# Out:
# [3759962, 3829893, 3908088, 3808806, 3848776, 3877594, 3766970, 3763017, 3764235, 3761459, 3789097, 3860165, 3800710, 3832131, 3879641, 3762133, 3765325, 3766561, 3763163, 3904074, 3820617, 3954918, 3803641, 3895498, 3842113, 3852410, 3759916, 3760416, 3770616, 3829237, 3767466, 3764113, 3833832, 3808694, 3810400, 3805381, 3951821, 3831803, 3763841, 3763583, 3950144, 3881762, 3811100, 3832260, 3765206, 3765658, 3867640, 3832333, 3809288, 3846490, 3765966, 3763875, 3755139, 3805200, 3847053, 3806422, 3910597, 3796731, 3776817, 3765359, 3816202, 3795525, 3908030, 3760046, 3903046, 3815262, 3807206, 3873716, 3758622, 3903530, 3820850, 3792204, 3903890, 3830580, 3812516, 3833161, 3832333, 3875317, 3811308, 3905604, 3832332, 3795813, 3951347, 3873287, 3825260, 3777657, 3764644, 3830788, 3766431, 3819515, 3803867, 3898330, 3812388, 3811504, 3898094, 3841051, 3761272, 3835589, 3849188, 3763804, 2145098, 2151065, 2165438, 2153514, 2148713, 2151628, 2220847, 2143916, 2168997, 2137404, 2060575, 2077122, 2236134, 2166589, 2150421, 2080411, 2147871, 2143857, 2146890, 2180680, 2261700, 2141564, 2100131, 2171755, 2071797, 2213671, 2166389, 2173187, 2145170, 2155062, 2149983, 2069722, 2153678, 2146032, 2061686, 2140606, 2102229, 2092691, 2096606, 2088971, 2131544, 2138358, 2092152, 2108637, 2120287, 2060002, 2155111, 2199393, 2177753, 2077122, 2285258, 2156627, 2097443, 2218833, 2220265, 2120197, 2071685, 2263296, 2197697, 2151508, 2184355, 2227736, 2264014, 2107379, 2102484, 2126818, 2090879, 2125521, 2173288, 2144354, 2103570, 2210976, 2175163, 2172943, 2153877, 2167228, 2189362, 2081672, 2231129, 2120576, 2145218, 2178068, 2098063, 2058349, 2143825, 2187417, 2147629, 2189979, 2111705, 2227784, 2116459, 2074161, 2106051, 2147387, 2143359, 2155366, 2075078, 2152607, 2233093, 2152652, 2172781, 2086397, 2062243, 2146363, 2366142, 2153941, 2156971, 2244198, 2126980, 2316550, 2135416, 2128020, 2295924, 2110163, 2127438, 2073159, 2282636, 2151611, 2154650, 2150486, 2377142, 2128323, 2320699, 2318235, 2406451, 2086381, 2126482, 2425142, 2054368, 2159910, 2126894, 2465052, 2353569, 2459311, 2161634, 2204136, 2377738, 2464913, 2090725, 2465078, 2529017, 2183508, 2329239, 2370968, 2138502, 2117065, 2174006, 2322943, 2126794, 2157254, 2109073, 2175491, 2363432, 2204040, 2159763, 2167264, 2155162, 2126613, 2111756, 2359600, 2108900, 2130054, 2086743, 2128820, 2081938, 2134653, 2052146, 2431327, 2447072, 2459612, 2137632, 2161288, 2317199, 2406149, 2139755, 2284597, 2093382, 2367256, 2280872, 2161294, 2139363, 2172187, 2093020, 2151055, 2099894, 2139529, 2126683, 2392355, 2126540, 2149738, 2129110, 2291597, 2129588, 2125225, 2173004, 2117609, 2151028, 2102278, 2228257, 2292945, 4975202, 5181874, 4751410, 5001395, 4833908, 5252764, 4480961, 4443265, 4587718, 5122037, 4943194, 4762191, 4200850, 4202556, 5003958, 4894439, 4750754, 5315025, 4669810, 4905454, 4735906, 5251393, 5139382, 4205305, 4831978, 5139058, 4995965, 3934028, 4635717, 4427140, 5121362, 4832031, 5073618, 5160313, 4690908, 4849867, 4719097, 4804599, 5263575, 5001607, 4481452, 5004174, 4755380, 4981634, 4927220, 4946371, 4341168, 4935462, 4573204, 4356505, 4614577, 4899727, 5002749, 5090898, 5137476, 4121457, 4520684, 5033536, 4640962, 5192367, 4748699, 5200543, 3871784, 4430865, 4648474, 3869157, 4765061, 4918178, 3428559, 3771179, 4634992, 4583301, 5066586, 5010677, 5054025, 4516251, 4542282, 4999770, 4947330, 4668867, 4669747, 4973014, 3929801, 4898836, 4909844, 4617408, 5192255, 4137442, 5475241, 4215678, 4854399, 4921765, 4750500, 5090722, 4073915, 5146033, 4925684, 5300954, 4715503, 4355071, 2933004, 2981283, 2935037, 2960664, 2645835, 2645513, 2806039, 2876839, 2814618, 2777007, 2766018, 2850676, 2651680, 2809844, 2925332, 2878573, 2913542, 2669409, 2773622, 2720117, 2836614, 2944135, 2796002, 2715815, 2616562, 2774775, 2734294, 2811859, 2745477, 2846687, 2805278, 2766477, 2825423, 3008782, 2720111, 3126847, 2642824, 2842776, 2569770, 2650140, 2932999, 2744246, 2806295, 2887653, 280 ...

# %%
def get_num_kmers(genome_file, kmer_length, canonical = False):
    genome_kmer = KMerSet(kmer_length, canonical = canonical)
    genome_kmer.insert_file(genome_file)
    return len(genome_kmer.set)

def compute_num_kmers_parallel(genome_files,kmer_length, canonical=False):
    with Pool(max_pool) as p:
        return p.starmap(get_num_kmers,([(g_file,kmer_length,canonical) for g_file in genome_files]))

# %%
kmer_counts = [0] * 40

# %%
canonical = True

# %%
for kmer_length in range(6,40):
    print(f"Processing kmers of length {kmer_length}")
    kmer_counts[kmer_length] = compute_num_kmers_parallel(checked_genome_files,kmer_length,canonical)
    fig = plt.figure(figsize=(5,5),dpi=600)
    ax = fig.add_subplot()
    ax.scatter(checked_genome_lengths,kmer_counts[kmer_length],marker="^",s=[2 for _ in checked_genome_lengths])
    ax.scatter(checked_genome_lengths, [min(4 ** kmer_length,genome_length) for genome_length in checked_genome_lengths],marker=".",s=[2 for _ in checked_genome_lengths])
    plt.plot()
    plt.savefig(f"../../plots/kmer_counting/{len(checked_genome_lengths)}genomes-{canonical=}-{kmer_length}mer-counts.png")
    plt.close()
# Out:
# Processing kmers of length 6
# Processing kmers of length 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 for kmer_length in range(6,40):
#       2     print(f"Processing kmers of length {kmer_length}")
# ----> 3     kmer_counts[kmer_length] = compute_num_kmers_parallel(checked_genome_files,kmer_length,canonical)
#       4     fig = plt.figure(figsize=(5,5),dpi=600)
#       5     ax = fig.add_subplot()
#
# Cell In[38], line 8, in compute_num_kmers_parallel(genome_files, kmer_length, canonical)
#       6 def compute_num_kmers_parallel(genome_files,kmer_length, canonical=False):
#       7     with Pool(max_pool) as p:
# ----> 8         return p.starmap(get_num_kmers,([(g_file,kmer_length,canonical) for g_file in genome_files]))
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/Desktop/UROP/GIS-2024/coding/ANI-est/lib/python3.12/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
Path(f"../../plots/kmer_counting/").mkdir(parents=True, exist_ok=True)

for kmer_length in range(6,23+1):
    fig = plt.figure(figsize=(5,5),dpi=600)
    ax = fig.add_subplot()
    ax.scatter(checked_genome_lengths,kmer_counts[kmer_length],marker="^",s=[2 for _ in checked_genome_lengths])
    ax.scatter(checked_genome_lengths, [min(4 ** kmer_length,genome_length) for genome_length in checked_genome_lengths],marker=".",s=[2 for _ in checked_genome_lengths])
    plt.plot()
    plt.savefig(f"../../plots/kmer_counting/{len(checked_genome_lengths)}genomes-{canonical=}-{kmer_length}mer-counts.png")
    plt.close()

# %%
import pandas as pd

# %%
kmer_counts_dict = {}
kmer_counts_dict['filename'] = checked_genome_files
for i in range(6,39+1):
    kmer_counts_dict[f"{i}-mer counts"] = kmer_counts[i]

# %%
kmer_counts_df = pd.DataFrame(kmer_counts_dict)

# %%
kmer_counts_df.to_csv(f"../../data_temp/kmer_counts-{canonical=}.csv")
